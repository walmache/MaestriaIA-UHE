# %%
# Instalamos las librerías necesarias
# !pip install opencv-python ultralytics
# Out:
# ^C
# Requirement already satisfied: opencv-python in c:\users\wilfrido a\appdata\local\programs\python\python312\lib\site-packages (4.10.0.82)
# WARNING: Retrying (Retry(total=4, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x000001C156267920>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed')': /simple/ultralytics/
# WARNING: Retrying (Retry(total=3, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x000001C1562803B0>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed')': /simple/ultralytics/
# WARNING: Retrying (Retry(total=2, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x000001C156280560>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed')': /simple/ultralytics/
# WARNING: Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x000001C156280770>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed')': /simple/ultralytics/
# WARNING: Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x000001C156280980>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed')': /simple/ultralytics/
# ERROR: Could not find a version that satisfies the requirement ultralytics (from versions: none)
# ERROR: No matching distribution found for ultralytics

# %%
# Importamos las librerías necesarias
from ultralytics import YOLO
import cv2
import math
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 2
#       1 # Importamos las librerías necesarias
# ----> 2 from ultralytics import YOLO
#       3 import cv2
#       4 import math
#
# ModuleNotFoundError: No module named 'ultralytics'

# %%
# Cargamos el modelo YOLO pre-entrenado en COCO dataset
model = YOLO("yolo-Weights/yolov8n.pt")

# %%
# Revisamos las clases que puede detectar el modelo
model.names
# Out:
# {0: 'person',
#  1: 'bicycle',
#  2: 'car',
#  3: 'motorcycle',
#  4: 'airplane',
#  5: 'bus',
#  6: 'train',
#  7: 'truck',
#  8: 'boat',
#  9: 'traffic light',
#  10: 'fire hydrant',
#  11: 'stop sign',
#  12: 'parking meter',
#  13: 'bench',
#  14: 'bird',
#  15: 'cat',
#  16: 'dog',
#  17: 'horse',
#  18: 'sheep',
#  19: 'cow',
#  20: 'elephant',
#  21: 'bear',
#  22: 'zebra',
#  23: 'giraffe',
#  24: 'backpack',
#  25: 'umbrella',
#  26: 'handbag',
#  27: 'tie',
#  28: 'suitcase',
#  29: 'frisbee',
#  30: 'skis',
#  31: 'snowboard',
#  32: 'sports ball',
#  33: 'kite',
#  34: 'baseball bat',
#  35: 'baseball glove',
#  36: 'skateboard',
#  37: 'surfboard',
#  38: 'tennis racket',
#  39: 'bottle',
#  40: 'wine glass',
#  41: 'cup',
#  42: 'fork',
#  43: 'knife',
#  44: 'spoon',
#  45: 'bowl',
#  46: 'banana',
#  47: 'apple',
#  48: 'sandwich',
#  49: 'orange',
#  50: 'broccoli',
#  51: 'carrot',
#  52: 'hot dog',
#  53: 'pizza',
#  54: 'donut',
#  55: 'cake',
#  56: 'chair',
#  57: 'couch',
#  58: 'potted plant',
#  59: 'bed',
#  60: 'dining table',
#  61: 'toilet',
#  62: 'tv',
#  63: 'laptop',
#  64: 'mouse',
#  65: 'remote',
#  66: 'keyboard',
#  67: 'cell phone',
#  68: 'microwave',
#  69: 'oven',
#  70: 'toaster',
#  71: 'sink',
#  72: 'refrigerator',
#  73: 'book',
#  74: 'clock',
#  75: 'vase',
#  76: 'scissors',
#  77: 'teddy bear',
#  78: 'hair drier',
#  79: 'toothbrush'}

# %%
# Definimos una lista de nombres con todas las clases para identificar objetos detectados
classNames = ["person", "bicycle", "car", "motorbike", "aeroplane", "bus", "train", "truck", "boat",
              "traffic light", "fire hydrant", "stop sign", "parking meter", "bench", "bird", "cat",
              "dog", "horse", "sheep", "cow", "elephant", "bear", "zebra", "giraffe", "backpack", "umbrella",
              "handbag", "tie", "suitcase", "frisbee", "skis", "snowboard", "sports ball", "kite", "baseball bat",
              "baseball glove", "skateboard", "surfboard", "tennis racket", "bottle", "wine glass", "cup",
              "fork", "knife", "spoon", "bowl", "banana", "apple", "sandwich", "orange", "broccoli",
              "carrot", "hot dog", "pizza", "donut", "cake", "chair", "sofa", "pottedplant", "bed",
              "diningtable", "toilet", "tvmonitor", "laptop", "mouse", "remote", "keyboard", "cell phone",
              "microwave", "oven", "toaster", "sink", "refrigerator", "book", "clock", "vase", "scissors",
              "teddy bear", "hair drier", "toothbrush"
              ] # Aquí se enumeran todas las clases

# %%
# Configuramos la captura de video desde la cámara
captura = cv2.VideoCapture(0) # Se abre la cámara por defecto

# Establecemos el ancho y alto de la imagen
captura.set(cv2.CAP_PROP_FRAME_WIDTH, 640) # Ancho de la imagen
captura.set(cv2.CAP_PROP_FRAME_HEIGHT, 480) # Alto de la imagen

# Iniciamos un bucle para procesar los fotogramas de la cámara
while True:
    success, img = captura.read() # Capturamos un fotograma

    # Realizamos la detección de objetos en la imagen capturada (usando el modelo de YOLO pre-entrenado que cargamos anteriormente)
    results = model(img, stream=True)

   # Procesamos los resultados de la detección
    for r in results:
        boxes = r.boxes

        # Iteramos sobre las cajas delimitadoras detectadas
        for box in boxes:
            # Obtenemos las coordenadas de la caja delimitadora
            x1, y1, x2, y2 = box.xyxy[0]
            x1, y1, x2, y2 = int(x1), int(y1), int(x2), int(y2) # Convertimos a valores enteros

            # Dibujamos la caja delimitadora en la imagen
            cv2.rectangle(img, (x1, y1), (x2, y2), (255, 0, 255), 1)

            # Obtenemos la confianza de la detección
            confidence = math.ceil((box.conf[0]*100))/100
            print("Confidence --->",confidence)

            # Obtenemos el nombre de la clase detectada
            cls = int(box.cls[0])
            print("Class name -->", classNames[cls])

            # Mostramos el nombre de la clase junto a la caja delimitadora
            org = [x1, y1]
            font = cv2.FONT_HERSHEY_SIMPLEX
            fontScale = 1
            color = (255, 0, 0) # Color: Azul (formato BGR)
            thickness = 1
            cv2.putText(img, classNames[cls], org, font, fontScale, color, thickness)

    # Mostramos la imagen con las detecciones
    cv2.imshow('Webcam', img)

    # Salimos del bucle si se presiona la tecla 'q'
    #if cv2.waitKey(1) == ord('q'):
    if cv2.waitKey(10) & 0xFF == ord('q'):
        break

# Liberamos la cámara y cerramos todas las ventanas
captura.release()
cv2.destroyAllWindows()
# Out:
# 0: 480x640 1 person, 153.6ms
# Confidence ---> 0.92
# Class name --> person
# Speed: 4.5ms preprocess, 153.6ms inference, 5.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 147.9ms
# Confidence ---> 0.92
# Class name --> person
# Speed: 2.4ms preprocess, 147.9ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 126.8ms
# Confidence ---> 0.92
# Class name --> person
# Speed: 1.6ms preprocess, 126.8ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 124.3ms
# Confidence ---> 0.93
# Class name --> person
# Speed: 1.4ms preprocess, 124.3ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 129.8ms
# Confidence ---> 0.92
# Class name --> person
# Speed: 2.0ms preprocess, 129.8ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 126.4ms
# Confidence ---> 0.93
# Class name --> person
# Speed: 2.0ms preprocess, 126.4ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 131.3ms
# Confidence ---> 0.93
# Class name --> person
# Speed: 3.1ms preprocess, 131.3ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 126.4ms
# Confidence ---> 0.92
# Class name --> person
# Speed: 1.8ms preprocess, 126.4ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 122.1ms
# Confidence ---> 0.93
# Class name --> person
# Speed: 2.3ms preprocess, 122.1ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 127.3ms
# Confidence ---> 0.92
# Class name --> person
# Speed: 1.3ms preprocess, 127.3ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 130.8ms
# Confidence ---> 0.93
# Class name --> person
# Speed: 1.5ms preprocess, 130.8ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 124.2ms
# Confidence ---> 0.92
# Class name --> person
# Speed: 1.7ms preprocess, 124.2ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 123.7ms
# Confidence ---> 0.92
# Class name --> person
# Speed: 2.6ms preprocess, 123.7ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 126.3ms
# Confidence ---> 0.93
# Class name --> person
# Speed: 2.0ms preprocess, 126.3ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 128.9ms
# Confidence ---> 0.92
# Class name --> person
# Speed: 2.3ms preprocess, 128.9ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 121.5ms
# Confidence ---> 0.92
# Class name --> person
# Speed: 2.2ms preprocess, 121.5ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 124.7ms
# Confidence ---> 0.94
# Class name --> person
# Speed: 2.1ms preprocess, 124.7ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 124.1ms
# Confidence ---> 0.94
# Class name --> person
# Speed: 2.2ms preprocess, 124.1ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 134.7ms
# Confidence ---> 0.93
# Class name --> person
# Speed: 2.4ms preprocess, 134.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 122.1ms
# Confidence ---> 0.94
# Class name --> person
# Speed: 2.9ms preprocess, 122.1ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 123.9ms
# Confidence ---> 0.94
# Class name --> person
# Speed: 2.1ms preprocess, 123.9ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cup, 131.5ms
# Confidence ---> 0.93
# Class name --> person
# Confidence ---> 0.28
# Class name --> cup
# Speed: 2.2ms preprocess, 131.5ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 118.6ms
# Confidence ---> 0.93
# Class name --> person
# Speed: 1.5ms preprocess, 118.6ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cup, 120.2ms
# Confidence ---> 0.93
# Class name --> person
# Confidence ---> 0.31
# Class name --> cup
# Speed: 1.4ms preprocess, 120.2ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 121.9ms
# Confidence ---> 0.93
# Class name --> person
# Speed: 1.3ms preprocess, 121.9ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cup, 130.0ms
# Confidence ---> 0.93
# Class name --> person
# Confidence ---> 0.32
# Class name --> cup
# Speed: 2.8ms preprocess, 130.0ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 120.7ms
# Confidence ---> 0.94
# Class name --> person
# Speed: 1.6ms preprocess, 120.7ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 121.2ms
# Confidence ---> 0.94
# Class name --> person
# Speed: 1.3ms preprocess, 121.2ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cup, 119.6ms
# Confidence ---> 0.94
# Class name --> person
# Confidence ---> 0.3
# Class name --> cup
# Speed: 1.8ms preprocess, 119.6ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 121.6ms
# Confidence ---> 0.94
# Class name --> person
# Speed: 2.2ms preprocess, 121.6ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 126.2ms
# Confidence ---> 0.94
# Class name --> person
# Speed: 2.0ms preprocess, 126.2ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 126.5ms
# Confidence ---> 0.94
# Class name --> person
# Speed: 2.6ms preprocess, 126.5ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 132.3ms
# Confidence ---> 0.94
# Class name --> person
# Speed: 2.3ms preprocess, 132.3ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 124.4ms
# Confidence ---> 0.94
# Class name --> person
# Speed: 1.3ms preprocess, 124.4ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 120.9ms
# Confidence ---> 0.93
# Class name --> person
# Speed: 1.9ms preprocess, 120.9ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 129.3ms
# Confidence ---> 0.94
# Class name --> person
# Speed: 1.5ms preprocess, 129.3ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 121.9ms
# Confidence ---> 0.94
# Class name --> person
# Speed: 2.2ms preprocess, 121.9ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 124.4ms
# Confidence ---> 0.95
# Class name --> person
# Speed: 2.1ms preprocess, 124.4ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 123.2ms
# Confidence ---> 0.95
# Class name --> person
# Confidence ---> 0.31
# Class name --> person
# Speed: 2.0ms preprocess, 123.2ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 126.8ms
# Confidence ---> 0.94
# Class name --> person
# Speed: 2.0ms preprocess, 126.8ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 123.6ms
# Confidence ---> 0.94
# Class name --> person
# Speed: 1.3ms preprocess, 123.6ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 129.0ms
# Confidence ---> 0.94
# Class name --> person
# Speed: 2.2ms preprocess, 129.0ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 125.1ms
# Confidence ---> 0.94
# Class name --> person
# Speed: 2.4ms preprocess, 125.1ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 128.4ms
# Confidence ---> 0.94
# Class name --> person
# Speed: 2.5ms preprocess, 128.4ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cup, 133.9ms
# Confidence ---> 0.94
# Class name --> person
# Confidence ---> 0.29
# Class name --> cup
# Speed: 2.2ms preprocess, 133.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 136.4ms
# Confidence ---> 0.93
# Class name --> person
# Speed: 1.7ms preprocess, 136.4ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 167.6ms
# Confidence ---> 0.93
# Class name --> person
# Speed: 2.4ms preprocess, 167.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 144.8ms
# Confidence ---> 0.93
# Class name --> person
# Speed: 1.6ms preprocess, 144.8ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 146.3ms
# Confidence ---> 0.93
# Class name --> person
# Speed: 1.5ms preprocess, 146.3ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 146.7ms
# Confidence ---> 0.94
# Class name --> person
# Speed: 2.6ms preprocess, 146.7ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 164.9ms
# Confidence ---> 0.94
# Class name --> person
# Speed: 1.5ms preprocess, 164.9ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 177.8ms
# Confidence ---> 0.94
# Class name --> person
# Speed: 1.8ms preprocess, 177.8ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 139.2ms
# Confidence ---> 0.93
# Class name --> person
# Speed: 4.1ms preprocess, 139.2ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 134.9ms
# Confidence ---> 0.93
# Class name --> person
# Speed: 2.3ms preprocess, 134.9ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 128.2ms
# Confidence ---> 0.94
# Class name --> person
# Speed: 2.1ms preprocess, 128.2ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 spoon, 133.0ms
# Confidence ---> 0.94
# Class name --> person
# Confidence ---> 0.28
# Class name --> spoon
# Speed: 1.3ms preprocess, 133.0ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 spoon, 128.3ms
# Confidence ---> 0.93
# Class name --> person
# Confidence ---> 0.35
# Class name --> spoon
# Speed: 1.4ms preprocess, 128.3ms inference, 8.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 132.0ms
# Confidence ---> 0.93
# Class name --> person
# Speed: 2.8ms preprocess, 132.0ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 135.2ms
# Confidence ---> 0.94
# Class name --> person
# Speed: 2.7ms preprocess, 135.2ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 129.3ms
# Confidence ---> 0.94
# Class name --> person
# Speed: 2.1ms preprocess, 129.3ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 128.8ms
# Confidence ---> 0.94
# Class name --> person
# Speed: 1.5ms preprocess, 128.8ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 spoon, 138.9ms
# Confidence ---> 0.94
# Class name --> person
# Confidence ---> 0.43
# Class name --> spoon
# Speed: 1.6ms preprocess, 138.9ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 spoon, 127.4ms
# Confidence ---> 0.94
# Class name --> person
# Confidence ---> 0.48
# Class name --> spoon
# Speed: 2.1ms preprocess, 127.4ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 spoon, 125.7ms
# Confidence ---> 0.94
# Class name --> person
# Confidence ---> 0.37
# Class name --> spoon
# Speed: 1.4ms preprocess, 125.7ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 spoon, 130.2ms
# Confidence ---> 0.93
# Class name --> person
# Confidence ---> 0.44
# Class name --> spoon
# Speed: 1.6ms preprocess, 130.2ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 spoon, 128.7ms
# Confidence ---> 0.93
# Class name --> person
# Confidence ---> 0.46
# Class name --> spoon
# Speed: 1.5ms preprocess, 128.7ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 spoon, 135.8ms
# Confidence ---> 0.94
# Class name --> person
# Confidence ---> 0.31
# Class name --> spoon
# Speed: 3.6ms preprocess, 135.8ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 spoon, 132.9ms
# Confidence ---> 0.94
# Class name --> person
# Confidence ---> 0.31
# Class name --> spoon
# Speed: 2.8ms preprocess, 132.9ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 spoon, 123.4ms
# Confidence ---> 0.94
# Class name --> person
# Confidence ---> 0.47
# Class name --> spoon
# Speed: 2.2ms preprocess, 123.4ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 spoon, 145.0ms
# Confidence ---> 0.93
# Class name --> person
# Confidence ---> 0.53
# Class name --> spoon
# Speed: 2.2ms preprocess, 145.0ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 132.6ms
# Confidence ---> 0.94
# Class name --> person
# Speed: 2.7ms preprocess, 132.6ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 spoon, 131.4ms
# Confidence ---> 0.94
# Class name --> person
# Confidence ---> 0.57
# Class name --> spoon
# Speed: 2.3ms preprocess, 131.4ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 spoon, 127.6ms
# Confidence ---> 0.94
# Class name --> person
# Confidence ---> 0.63
# Class name --> spoon
# Speed: 1.3ms preprocess, 127.6ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 spoon, 124.3ms
# Confidence ---> 0.94
# Class name --> person
# Confidence ---> 0.48
# Class name --> spoon
# Speed: 1.6ms preprocess, 124.3ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 spoon, 123.7ms
# Confidence ---> 0.93
# Class name --> person
# Confidence ---> 0.61
# Class name --> spoon
# Speed: 2.5ms preprocess, 123.7ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 spoon, 126.2ms
# Confidence ---> 0.94
# Class name --> person
# Confidence ---> 0.64
# Class name --> spoon
# Speed: 2.1ms preprocess, 126.2ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 spoon, 120.7ms
# Confidence ---> 0.94
# Class name --> person
# Confidence ---> 0.61
# Class name --> spoon
# Speed: 1.6ms preprocess, 120.7ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 124.3ms
# Confidence ---> 0.92
# Class name --> person
# Speed: 2.0ms preprocess, 124.3ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 122.8ms
# Confidence ---> 0.92
# Class name --> person
# Speed: 1.4ms preprocess, 122.8ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 toothbrush, 135.8ms
# Confidence ---> 0.93
# Class name --> person
# Confidence ---> 0.48
# Class name --> toothbrush
# Speed: 2.0ms preprocess, 135.8ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 146.1ms
# Confidence ---> 0.93
# Class name --> person
# Speed: 2.0ms preprocess, 146.1ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cup, 127.4ms
# Confidence ---> 0.94
# Class name --> person
# Confidence ---> 0.5
# Class name --> cup
# Speed: 1.7ms preprocess, 127.4ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cup, 127.5ms
# Confidence ---> 0.93
# Class name --> person
# Confidence ---> 0.75
# Class name --> cup
# Speed: 2.6ms preprocess, 127.5ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cup, 126.0ms
# Confidence ---> 0.92
# Class name --> person
# Confidence ---> 0.51
# Class name --> cup
# Speed: 2.5ms preprocess, 126.0ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cup, 128.3ms
# Confidence ---> 0.93
# Class name --> person
# Confidence ---> 0.56
# Class name --> cup
# Speed: 2.1ms preprocess, 128.3ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cup, 126.1ms
# Confidence ---> 0.94
# Class name --> person
# Confidence ---> 0.51
# Class name --> cup
# Speed: 2.2ms preprocess, 126.1ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 124.8ms
# Confidence ---> 0.94
# Class name --> person
# Speed: 2.9ms preprocess, 124.8ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cup, 122.1ms
# Confidence ---> 0.93
# Class name --> person
# Confidence ---> 0.52
# Class name --> cup
# Speed: 3.1ms preprocess, 122.1ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cup, 126.1ms
# Confidence ---> 0.92
# Class name --> person
# Confidence ---> 0.59
# Class name --> cup
# Speed: 2.1ms preprocess, 126.1ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 125.0ms
# Confidence ---> 0.93
# Class name --> person
# Speed: 1.6ms preprocess, 125.0ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cup, 122.3ms
# Confidence ---> 0.92
# Class name --> person
# Confidence ---> 0.59
# Class name --> cup
# Speed: 2.0ms preprocess, 122.3ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 124.6ms
# Confidence ---> 0.92
# Class name --> person
# Speed: 2.2ms preprocess, 124.6ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 125.0ms
# Confidence ---> 0.93
# Class name --> person
# Speed: 2.8ms preprocess, 125.0ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 122.0ms
# Confidence ---> 0.92
# Class name --> person
# Speed: 1.3ms preprocess, 122.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 123.3ms
# Confidence ---> 0.81
# Class name --> person
# Speed: 2.1ms preprocess, 123.3ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 125.2ms
# Confidence ---> 0.89
# Class name --> person
# Confidence ---> 0.31
# Class name --> person
# Confidence ---> 0.28
# Class name --> person
# Speed: 1.3ms preprocess, 125.2ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 120.7ms
# Confidence ---> 0.93
# Class name --> person
# Speed: 2.5ms preprocess, 120.7ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 125.5ms
# Confidence ---> 0.92
# Class name --> person
# Speed: 2.8ms preprocess, 125.5ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 142.5ms
# Confidence ---> 0.91
# Class name --> person
# Speed: 2.6ms preprocess, 142.5ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 136.0ms
# Confidence ---> 0.93
# Class name --> person
# Speed: 2.4ms preprocess, 136.0ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 123.7ms
# Confidence ---> 0.93
# Class name --> person
# Confidence ---> 0.3
# Class name --> person
# Speed: 2.2ms preprocess, 123.7ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 cup, 123.6ms
# Confidence ---> 0.93
# Class name --> person
# Confidence ---> 0.38
# Class name --> person
# Confidence ---> 0.27
# Class name --> cup
# Speed: 1.6ms preprocess, 123.6ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 121.6ms
# Confidence ---> 0.93
# Class name --> person
# Speed: 2.1ms preprocess, 121.6ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 125.2ms
# Confidence ---> 0.93
# Class name --> person
# Speed: 3.6ms preprocess, 125.2ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 122.2ms
# Confidence ---> 0.92
# Class name --> person
# Speed: 2.5ms preprocess, 122.2ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 125.6ms
# Confidence ---> 0.93
# Class name --> person
# Speed: 2.1ms preprocess, 125.6ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 124.8ms
# Confidence ---> 0.93
# Class name --> person
# Speed: 2.0ms preprocess, 124.8ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 120.2ms
# Confidence ---> 0.92
# Class name --> person
# Speed: 1.7ms preprocess, 120.2ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 119.9ms
# Confidence ---> 0.93
# Class name --> person
# Speed: 1.5ms preprocess, 119.9ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 121.1ms
# Confidence ---> 0.92
# Class name --> person
# Speed: 2.0ms preprocess, 121.1ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 122.6ms
# Confidence ---> 0.92
# Class name --> person
# Speed: 2.3ms preprocess, 122.6ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 125.4ms
# Confidence ---> 0.93
# Class name --> person
# Speed: 2.2ms preprocess, 125.4ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 125.8ms
# Confidence ---> 0.92
# Class name --> person
# Speed: 2.0ms preprocess, 125.8ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 123.8ms
# Confidence ---> 0.93
# Class name --> person
# Speed: 1.7ms preprocess, 123.8ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 120.5ms
# Confidence ---> 0.93
# Class name --> person
# Speed: 1.3ms preprocess, 120.5ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 123.4ms
# Confidence ---> 0.93
# Class name --> person
# Speed: 1.6ms preprocess, 123.4ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cup, 118.9ms
# Confidence ---> 0.92
# Class name --> person
# Confidence ---> 0.39
# Class name --> cup
# Speed: 1.2ms preprocess, 118.9ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cup, 122.6ms
# Confidence ---> 0.91
# Class name --> person
# Confidence ---> 0.41
# Class name --> cup
# Speed: 2.0ms preprocess, 122.6ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cup, 121.6ms
# Confidence ---> 0.9
# Class name --> person
# Confidence ---> 0.47
# Class name --> cup
# Speed: 2.0ms preprocess, 121.6ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cup, 125.0ms
# Confidence ---> 0.9
# Class name --> person
# Confidence ---> 0.49
# Class name --> cup
# Speed: 2.1ms preprocess, 125.0ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cup, 124.4ms
# Confidence ---> 0.9
# Class name --> person
# Confidence ---> 0.34
# Class name --> cup
# Speed: 1.4ms preprocess, 124.4ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cup, 124.5ms
# Confidence ---> 0.93
# Class name --> person
# Confidence ---> 0.62
# Class name --> cup
# Speed: 2.2ms preprocess, 124.5ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cup, 147.9ms
# Confidence ---> 0.93
# Class name --> person
# Confidence ---> 0.48
# Class name --> cup
# Speed: 2.4ms preprocess, 147.9ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 129.3ms
# Confidence ---> 0.92
# Class name --> person
# Speed: 2.0ms preprocess, 129.3ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cup, 126.9ms
# Confidence ---> 0.93
# Class name --> person
# Confidence ---> 0.43
# Class name --> cup
# Speed: 2.5ms preprocess, 126.9ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cup, 1 cell phone, 128.2ms
# Confidence ---> 0.93
# Class name --> person
# Confidence ---> 0.43
# Class name --> cup
# Confidence ---> 0.28
# Class name --> cell phone
# Speed: 2.0ms preprocess, 128.2ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cup, 142.8ms
# Confidence ---> 0.93
# Class name --> person
# Confidence ---> 0.53
# Class name --> cup
# Speed: 2.8ms preprocess, 142.8ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cup, 138.5ms
# Confidence ---> 0.92
# Class name --> person
# Confidence ---> 0.51
# Class name --> cup
# Speed: 1.7ms preprocess, 138.5ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cup, 131.5ms
# Confidence ---> 0.93
# Class name --> person
# Confidence ---> 0.43
# Class name --> cup
# Speed: 1.8ms preprocess, 131.5ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cup, 130.0ms
# Confidence ---> 0.92
# Class name --> person
# Confidence ---> 0.51
# Class name --> cup
# Speed: 3.2ms preprocess, 130.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cup, 129.3ms
# Confidence ---> 0.93
# Class name --> person
# Confidence ---> 0.45
# Class name --> cup
# Speed: 1.6ms preprocess, 129.3ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cup, 125.0ms
# Confidence ---> 0.93
# Class name --> person
# Confidence ---> 0.48
# Class name --> cup
# Speed: 2.4ms preprocess, 125.0ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cup, 125.4ms
# Confidence ---> 0.92
# Class name --> person
# Confidence ---> 0.54
# Class name --> cup
# Speed: 1.4ms preprocess, 125.4ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cup, 133.3ms
# Confidence ---> 0.93
# Class name --> person
# Confidence ---> 0.33
# Class name --> cup
# Speed: 1.3ms preprocess, 133.3ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cup, 121.7ms
# Confidence ---> 0.93
# Class name --> person
# Confidence ---> 0.52
# Class name --> cup
# Speed: 1.4ms preprocess, 121.7ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cup, 127.2ms
# Confidence ---> 0.93
# Class name --> person
# Confidence ---> 0.41
# Class name --> cup
# Speed: 2.6ms preprocess, 127.2ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cup, 123.7ms
# Confidence ---> 0.93
# Class name --> person
# Confidence ---> 0.6
# Class name --> cup
# Speed: 1.3ms preprocess, 123.7ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cup, 123.7ms
# Confidence ---> 0.93
# Class name --> person
# Confidence ---> 0.47
# Class name --> cup
# Speed: 2.1ms preprocess, 123.7ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cup, 131.2ms
# Confidence ---> 0.92
# Class name --> person
# Confidence ---> 0.49
# Class name --> cup
# Speed: 2.6ms preprocess, 131.2ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cup, 129.7ms
# Confidence ---> 0.94
# Class name --> person
# Confidence ---> 0.53
# Class name --> cup
# Speed: 2.4ms preprocess, 129.7ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cup, 128.8ms
# Confidence ---> 0.91
# Class name --> person
# Confidence ---> 0.26
# Class name --> cup
# Speed: 2.3ms preprocess, 128.8ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 125.6ms
# Confidence ---> 0.89
# Class name --> person
# Speed: 2.2ms preprocess, 125.6ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 130.2ms
# Confidence ---> 0.92
# Class name --> person
# Speed: 2.2ms preprocess, 130.2ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 127.4ms
# Confidence ---> 0.93
# Class name --> person
# Speed: 2.2ms preprocess, 127.4ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 wine glass, 1 cup, 124.3ms
# Confidence ---> 0.92
# Class name --> person
# Confidence ---> 0.43
# Class name --> cup
# Confidence ---> 0.32
# Class name --> wine glass
# Speed: 1.4ms preprocess, 124.3ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 wine glass, 122.2ms
# Confidence ---> 0.92
# Class name --> person
# Confidence ---> 0.38
# Class name --> wine glass
# Speed: 2.9ms preprocess, 122.2ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 wine glass, 127.6ms
# Confidence ---> 0.92
# Class name --> person
# Confidence ---> 0.3
# Class name --> wine glass
# Speed: 2.1ms preprocess, 127.6ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 125.6ms
# Confidence ---> 0.93
# Class name --> person
# Speed: 2.1ms preprocess, 125.6ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 124.9ms
# Confidence ---> 0.93
# Class name --> person
# Speed: 2.4ms preprocess, 124.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 128.9ms
# Confidence ---> 0.9
# Class name --> person
# Speed: 2.1ms preprocess, 128.9ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 136.4ms
# Confidence ---> 0.92
# Class name --> person
# Confidence ---> 0.28
# Class name --> cell phone
# Speed: 1.7ms preprocess, 136.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 143.6ms
# Confidence ---> 0.92
# Class name --> person
# Speed: 2.4ms preprocess, 143.6ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 135.0ms
# Confidence ---> 0.92
# Class name --> person
# Speed: 2.5ms preprocess, 135.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 129.3ms
# Confidence ---> 0.93
# Class name --> person
# Confidence ---> 0.32
# Class name --> cell phone
# Speed: 1.4ms preprocess, 129.3ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 128.5ms
# Confidence ---> 0.92
# Class name --> person
# Speed: 2.3ms preprocess, 128.5ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 128.2ms
# Confidence ---> 0.92
# Class name --> person
# Speed: 2.1ms preprocess, 128.2ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 125.7ms
# Confidence ---> 0.91
# Class name --> person
# Speed: 2.6ms preprocess, 125.7ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 121.7ms
# Confidence ---> 0.92
# Class name --> person
# Speed: 2.4ms preprocess, 121.7ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 122.4ms
# Confidence ---> 0.9
# Class name --> person
# Speed: 1.3ms preprocess, 122.4ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 121.6ms
# Confidence ---> 0.92
# Class name --> person
# Speed: 2.0ms preprocess, 121.6ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 128.6ms
# Confidence ---> 0.91
# Class name --> person
# Speed: 1.3ms preprocess, 128.6ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 122.0ms
# Confidence ---> 0.92
# Class name --> person
# Speed: 3.1ms preprocess, 122.0ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 125.4ms
# Confidence ---> 0.9
# Class name --> person
# Speed: 2.0ms preprocess, 125.4ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 175.3ms
# Confidence ---> 0.92
# Class name --> person
# Speed: 1.7ms preprocess, 175.3ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 wine glasss, 133.4ms
# Confidence ---> 0.92
# Class name --> person
# Confidence ---> 0.38
# Class name --> wine glass
# Confidence ---> 0.33
# Class name --> wine glass
# Speed: 1.7ms preprocess, 133.4ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 wine glass, 135.0ms
# Confidence ---> 0.92
# Class name --> person
# Confidence ---> 0.33
# Class name --> wine glass
# Speed: 1.2ms preprocess, 135.0ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 wine glass, 135.6ms
# Confidence ---> 0.93
# Class name --> person
# Confidence ---> 0.26
# Class name --> wine glass
# Speed: 2.3ms preprocess, 135.6ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 wine glass, 134.2ms
# Confidence ---> 0.92
# Class name --> person
# Confidence ---> 0.26
# Class name --> wine glass
# Speed: 1.7ms preprocess, 134.2ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 126.3ms
# Confidence ---> 0.93
# Class name --> person
# Speed: 3.1ms preprocess, 126.3ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 123.1ms
# Confidence ---> 0.92
# Class name --> person
# Speed: 1.6ms preprocess, 123.1ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 125.8ms
# Confidence ---> 0.92
# Class name --> person
# Speed: 1.3ms preprocess, 125.8ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 121.0ms
# Confidence ---> 0.93
# Class name --> person
# Speed: 2.8ms preprocess, 121.0ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 119.7ms
# Confidence ---> 0.94
# Class name --> person
# Speed: 1.3ms preprocess, 119.7ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 123.2ms
# Confidence ---> 0.93
# Class name --> person
# Speed: 1.8ms preprocess, 123.2ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 126.6ms
# Confidence ---> 0.92
# Class name --> person
# Speed: 2.2ms preprocess, 126.6ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 121.0ms
# Confidence ---> 0.93
# Class name --> person
# Speed: 1.4ms preprocess, 121.0ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 121.0ms
# Confidence ---> 0.92
# Class name --> person
# Speed: 1.3ms preprocess, 121.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 119.3ms
# Confidence ---> 0.92
# Class name --> person
# Speed: 1.5ms preprocess, 119.3ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 125.0ms
# Confidence ---> 0.92
# Class name --> person
# Speed: 2.8ms preprocess, 125.0ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 128.9ms
# Confidence ---> 0.9
# Class name --> person
# Speed: 2.9ms preprocess, 128.9ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 134.4ms
# Confidence ---> 0.92
# Class name --> person
# Speed: 3.4ms preprocess, 134.4ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 123.0ms
# Confidence ---> 0.92
# Class name --> person
# Speed: 1.2ms preprocess, 123.0ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 124.2ms
# Confidence ---> 0.91
# Class name --> person
# Speed: 2.5ms preprocess, 124.2ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 124.7ms
# Confidence ---> 0.91
# Class name --> person
# Speed: 2.1ms preprocess, 124.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cup, 120.9ms
# Confidence ---> 0.92
# Class name --> person
# Confidence ---> 0.45
# Class name --> cup
# Speed: 2.5ms preprocess, 120.9ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 123.0ms
# Confidence ---> 0.91
# Class name --> person
# Speed: 2.1ms preprocess, 123.0ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 122.6ms
# Confidence ---> 0.91
# Class name --> person
# Speed: 2.3ms preprocess, 122.6ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 125.3ms
# Confidence ---> 0.92
# Class name --> person
# Speed: 2.0ms preprocess, 125.3ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 122.0ms
# Confidence ---> 0.92
# Class name --> person
# Speed: 2.4ms preprocess, 122.0ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 124.4ms
# Confidence ---> 0.92
# Class name --> person
# Speed: 2.8ms preprocess, 124.4ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cup, 125.4ms
# Confidence ---> 0.93
# Class name --> person
# Confidence ---> 0.38
# Class name --> cup
# Speed: 2.1ms preprocess, 125.4ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cup, 121.4ms
# Confidence ---> 0.92
# Class name --> person
# Confidence ---> 0.42
# Class name --> cup
# Speed: 2.1ms preprocess, 121.4ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 123.1ms
# Confidence ---> 0.94
# Class name --> person
# Speed: 2.6ms preprocess, 123.1ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 126.3ms
# Confidence ---> 0.94
# Class name --> person
# Speed: 2.1ms preprocess, 126.3ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cup, 123.5ms
# Confidence ---> 0.94
# Class name --> person
# Confidence ---> 0.41
# Class name --> cup
# Speed: 1.4ms preprocess, 123.5ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 143.3ms
# Confidence ---> 0.93
# Class name --> person
# Speed: 2.0ms preprocess, 143.3ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 125.0ms
# Confidence ---> 0.94
# Class name --> person
# Speed: 2.1ms preprocess, 125.0ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 123.9ms
# Confidence ---> 0.92
# Class name --> person
# Speed: 2.6ms preprocess, 123.9ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 121.8ms
# Confidence ---> 0.84
# Class name --> person
# Speed: 1.2ms preprocess, 121.8ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 cell phones, 119.7ms
# Confidence ---> 0.91
# Class name --> person
# Confidence ---> 0.49
# Class name --> cell phone
# Confidence ---> 0.35
# Class name --> cell phone
# Speed: 1.4ms preprocess, 119.7ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 123.7ms
# Confidence ---> 0.86
# Class name --> person
# Confidence ---> 0.45
# Class name --> cell phone
# Speed: 2.1ms preprocess, 123.7ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 120.2ms
# Confidence ---> 0.87
# Class name --> person
# Confidence ---> 0.52
# Class name --> cell phone
# Speed: 1.6ms preprocess, 120.2ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 125.0ms
# Confidence ---> 0.85
# Class name --> person
# Confidence ---> 0.31
# Class name --> cell phone
# Speed: 2.2ms preprocess, 125.0ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 snowboard, 1 cup, 121.7ms
# Confidence ---> 0.82
# Class name --> person
# Confidence ---> 0.6
# Class name --> snowboard
# Confidence ---> 0.29
# Class name --> cup
# Speed: 3.1ms preprocess, 121.7ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 snowboard, 1 cup, 125.6ms
# Confidence ---> 0.82
# Class name --> person
# Confidence ---> 0.46
# Class name --> cup
# Confidence ---> 0.46
# Class name --> snowboard
# Speed: 1.3ms preprocess, 125.6ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 snowboard, 1 cup, 127.0ms
# Confidence ---> 0.83
# Class name --> person
# Confidence ---> 0.5
# Class name --> snowboard
# Confidence ---> 0.39
# Class name --> cup
# Speed: 2.1ms preprocess, 127.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 snowboard, 1 cup, 1 cell phone, 121.5ms
# Confidence ---> 0.88
# Class name --> person
# Confidence ---> 0.64
# Class name --> cell phone
# Confidence ---> 0.5
# Class name --> cup
# Confidence ---> 0.49
# Class name --> snowboard
# Speed: 2.2ms preprocess, 121.5ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 snowboard, 1 cup, 1 cell phone, 129.6ms
# Confidence ---> 0.89
# Class name --> person
# Confidence ---> 0.72
# Class name --> cell phone
# Confidence ---> 0.55
# Class name --> cup
# Confidence ---> 0.3
# Class name --> snowboard
# Speed: 2.0ms preprocess, 129.6ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cup, 1 cell phone, 126.1ms
# Confidence ---> 0.9
# Class name --> person
# Confidence ---> 0.63
# Class name --> cell phone
# Confidence ---> 0.62
# Class name --> cup
# Speed: 2.2ms preprocess, 126.1ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cup, 1 cell phone, 122.0ms
# Confidence ---> 0.91
# Class name --> person
# Confidence ---> 0.69
# Class name --> cell phone
# Confidence ---> 0.5
# Class name --> cup
# Speed: 1.6ms preprocess, 122.0ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 snowboard, 1 cup, 122.6ms
# Confidence ---> 0.88
# Class name --> person
# Confidence ---> 0.43
# Class name --> cup
# Confidence ---> 0.4
# Class name --> snowboard
# Speed: 2.1ms preprocess, 122.6ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 snowboard, 1 cup, 1 cell phone, 126.8ms
# Confidence ---> 0.89
# Class name --> person
# Confidence ---> 0.57
# Class name --> cell phone
# Confidence ---> 0.51
# Class name --> cup
# Confidence ---> 0.37
# Class name --> snowboard
# Speed: 1.6ms preprocess, 126.8ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 snowboard, 1 cup, 121.9ms
# Confidence ---> 0.89
# Class name --> person
# Confidence ---> 0.6
# Class name --> cup
# Confidence ---> 0.39
# Class name --> snowboard
# Speed: 2.2ms preprocess, 121.9ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 snowboard, 1 cup, 127.1ms
# Confidence ---> 0.9
# Class name --> person
# Confidence ---> 0.61
# Class name --> cup
# Confidence ---> 0.5
# Class name --> snowboard
# Speed: 1.3ms preprocess, 127.1ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cup, 130.8ms
# Confidence ---> 0.92
# Class name --> person
# Confidence ---> 0.57
# Class name --> cup
# Speed: 2.0ms preprocess, 130.8ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cup, 124.6ms
# Confidence ---> 0.94
# Class name --> person
# Confidence ---> 0.52
# Class name --> cup
# Speed: 2.1ms preprocess, 124.6ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cup, 123.4ms
# Confidence ---> 0.93
# Class name --> person
# Confidence ---> 0.56
# Class name --> cup
# Speed: 2.6ms preprocess, 123.4ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cup, 125.1ms
# Confidence ---> 0.93
# Class name --> person
# Confidence ---> 0.52
# Class name --> cup
# Speed: 1.3ms preprocess, 125.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cup, 124.5ms
# Confidence ---> 0.94
# Class name --> person
# Confidence ---> 0.51
# Class name --> cup
# Speed: 2.3ms preprocess, 124.5ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cup, 121.5ms
# Confidence ---> 0.93
# Class name --> person
# Confidence ---> 0.48
# Class name --> cup
# Speed: 2.6ms preprocess, 121.5ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cup, 125.2ms
# Confidence ---> 0.94
# Class name --> person
# Confidence ---> 0.5
# Class name --> cup
# Speed: 2.0ms preprocess, 125.2ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cup, 135.5ms
# Confidence ---> 0.94
# Class name --> person
# Confidence ---> 0.43
# Class name --> cup
# Speed: 2.3ms preprocess, 135.5ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cup, 127.9ms
# Confidence ---> 0.94
# Class name --> person
# Confidence ---> 0.48
# Class name --> cup
# Speed: 2.2ms preprocess, 127.9ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cup, 125.1ms
# Confidence ---> 0.93
# Class name --> person
# Confidence ---> 0.43
# Class name --> cup
# Speed: 1.4ms preprocess, 125.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cup, 130.4ms
# Confidence ---> 0.93
# Class name --> person
# Confidence ---> 0.52
# Class name --> cup
# Speed: 3.1ms preprocess, 130.4ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cup, 127.8ms
# Confidence ---> 0.93
# Class name --> person
# Confidence ---> 0.49
# Class name --> cup
# Speed: 2.5ms preprocess, 127.8ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cup, 119.2ms
# Confidence ---> 0.93
# Class name --> person
# Confidence ---> 0.5
# Class name --> cup
# Speed: 1.4ms preprocess, 119.2ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cup, 122.1ms
# Confidence ---> 0.85
# Class name --> person
# Confidence ---> 0.44
# Class name --> cup
# Speed: 1.3ms preprocess, 122.1ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cup, 122.9ms
# Confidence ---> 0.67
# Class name --> person
# Confidence ---> 0.59
# Class name --> cup
# Speed: 1.4ms preprocess, 122.9ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cup, 128.2ms
# Confidence ---> 0.72
# Class name --> person
# Confidence ---> 0.58
# Class name --> cup
# Speed: 2.2ms preprocess, 128.2ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cup, 120.4ms
# Confidence ---> 0.73
# Class name --> person
# Confidence ---> 0.58
# Class name --> cup
# Speed: 2.3ms preprocess, 120.4ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cup, 122.3ms
# Confidence ---> 0.77
# Class name --> person
# Confidence ---> 0.45
# Class name --> cup
# Speed: 2.4ms preprocess, 122.3ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cup, 125.2ms
# Confidence ---> 0.76
# Class name --> person
# Confidence ---> 0.54
# Class name --> cup
# Speed: 2.3ms preprocess, 125.2ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cup, 118.8ms
# Confidence ---> 0.7
# Class name --> person
# Confidence ---> 0.36
# Class name --> cup
# Speed: 2.0ms preprocess, 118.8ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cup, 127.7ms
# Confidence ---> 0.71
# Class name --> person
# Confidence ---> 0.37
# Class name --> cup
# Speed: 1.7ms preprocess, 127.7ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cup, 126.8ms
# Confidence ---> 0.79
# Class name --> person
# Confidence ---> 0.62
# Class name --> cup
# Speed: 2.1ms preprocess, 126.8ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cup, 127.6ms
# Confidence ---> 0.72
# Class name --> person
# Confidence ---> 0.46
# Class name --> cup
# Speed: 2.7ms preprocess, 127.6ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cup, 121.4ms
# Confidence ---> 0.73
# Class name --> person
# Confidence ---> 0.53
# Class name --> cup
# Speed: 2.4ms preprocess, 121.4ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cup, 122.3ms
# Confidence ---> 0.78
# Class name --> person
# Confidence ---> 0.52
# Class name --> cup
# Speed: 2.2ms preprocess, 122.3ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cup, 120.6ms
# Confidence ---> 0.75
# Class name --> person
# Confidence ---> 0.56
# Class name --> cup
# Speed: 1.3ms preprocess, 120.6ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cup, 1 chair, 121.6ms
# Confidence ---> 0.71
# Class name --> person
# Confidence ---> 0.52
# Class name --> cup
# Confidence ---> 0.28
# Class name --> chair
# Speed: 2.3ms preprocess, 121.6ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# ...
#
# 0: 480x640 1 person, 1 laptop, 123.1ms
# Confidence ---> 0.86
# Class name --> person
# Confidence ---> 0.37
# Class name --> laptop
# Speed: 2.1ms preprocess, 123.1ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 cup, 1 laptop, 121.2ms
# Confidence ---> 0.77
# Class name --> person
# Confidence ---> 0.46
# Class name --> laptop
# Confidence ---> 0.3
# Class name --> person
# Confidence ---> 0.29
# Class name --> cup
# Speed: 2.5ms preprocess, 121.2ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cup, 1 laptop, 123.9ms
# Confidence ---> 0.83
# Class name --> person
# Confidence ---> 0.3
# Class name --> cup
# Confidence ---> 0.29
# Class name --> laptop
# Speed: 2.1ms preprocess, 123.9ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 cup, 1 laptop, 124.7ms
# Confidence ---> 0.78
# Class name --> person
# Confidence ---> 0.36
# Class name --> cup
# Confidence ---> 0.28
# Class name --> person
# Confidence ---> 0.28
# Class name --> laptop
# Speed: 2.8ms preprocess, 124.7ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 1 cup, 1 laptop, 123.0ms
# Confidence ---> 0.75
# Class name --> person
# Confidence ---> 0.36
# Class name --> cup
# Confidence ---> 0.34
# Class name --> person
# Confidence ---> 0.31
# Class name --> person
# Confidence ---> 0.29
# Class name --> laptop
# Speed: 2.1ms preprocess, 123.0ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 cup, 1 laptop, 119.9ms
# Confidence ---> 0.76
# Class name --> person
# Confidence ---> 0.47
# Class name --> cup
# Confidence ---> 0.35
# Class name --> laptop
# Confidence ---> 0.32
# Class name --> person
# Speed: 2.1ms preprocess, 119.9ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 laptop, 123.1ms
# Confidence ---> 0.76
# Class name --> person
# Confidence ---> 0.34
# Class name --> laptop
# Confidence ---> 0.3
# Class name --> person
# Speed: 2.6ms preprocess, 123.1ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 cup, 1 laptop, 119.3ms
# Confidence ---> 0.82
# Class name --> person
# Confidence ---> 0.42
# Class name --> cup
# Confidence ---> 0.37
# Class name --> laptop
# Confidence ---> 0.3
# Class name --> person
# Speed: 1.6ms preprocess, 119.3ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 cup, 1 laptop, 123.4ms
# Confidence ---> 0.78
# Class name --> person
# Confidence ---> 0.42
# Class name --> laptop
# Confidence ---> 0.41
# Class name --> cup
# Confidence ---> 0.36
# Class name --> person
# Speed: 2.4ms preprocess, 123.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 cup, 1 laptop, 139.8ms
# Confidence ---> 0.85
# Class name --> person
# Confidence ---> 0.41
# Class name --> laptop
# Confidence ---> 0.37
# Class name --> person
# Confidence ---> 0.36
# Class name --> cup
# Speed: 1.3ms preprocess, 139.8ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 cup, 1 laptop, 130.3ms
# Confidence ---> 0.85
# Class name --> person
# Confidence ---> 0.33
# Class name --> person
# Confidence ---> 0.32
# Class name --> laptop
# Confidence ---> 0.27
# Class name --> cup
# Speed: 2.8ms preprocess, 130.3ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 cup, 1 laptop, 130.7ms
# Confidence ---> 0.84
# Class name --> person
# Confidence ---> 0.36
# Class name --> person
# Confidence ---> 0.33
# Class name --> cup
# Confidence ---> 0.3
# Class name --> laptop
# Speed: 1.7ms preprocess, 130.7ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 laptop, 131.3ms
# Confidence ---> 0.77
# Class name --> person
# Confidence ---> 0.45
# Class name --> person
# Confidence ---> 0.44
# Class name --> laptop
# Speed: 2.2ms preprocess, 131.3ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 cup, 1 laptop, 125.3ms
# Confidence ---> 0.77
# Class name --> person
# Confidence ---> 0.39
# Class name --> person
# Confidence ---> 0.38
# Class name --> laptop
# Confidence ---> 0.28
# Class name --> cup
# Speed: 2.1ms preprocess, 125.3ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 laptop, 124.6ms
# Confidence ---> 0.84
# Class name --> person
# Confidence ---> 0.52
# Class name --> laptop
# Confidence ---> 0.36
# Class name --> person
# Speed: 2.3ms preprocess, 124.6ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 cup, 1 laptop, 128.8ms
# Confidence ---> 0.83
# Class name --> person
# Confidence ---> 0.42
# Class name --> person
# Confidence ---> 0.31
# Class name --> cup
# Confidence ---> 0.28
# Class name --> laptop
# Speed: 2.3ms preprocess, 128.8ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cup, 1 laptop, 127.8ms
# Confidence ---> 0.87
# Class name --> person
# Confidence ---> 0.37
# Class name --> cup
# Confidence ---> 0.34
# Class name --> laptop
# Speed: 2.4ms preprocess, 127.8ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 126.0ms
# Confidence ---> 0.89
# Class name --> person
# Confidence ---> 0.32
# Class name --> person
# Speed: 2.1ms preprocess, 126.0ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 laptop, 124.2ms
# Confidence ---> 0.87
# Class name --> person
# Confidence ---> 0.47
# Class name --> laptop
# Confidence ---> 0.37
# Class name --> person
# Speed: 2.2ms preprocess, 124.2ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 cup, 120.2ms
# Confidence ---> 0.82
# Class name --> person
# Confidence ---> 0.38
# Class name --> person
# Confidence ---> 0.26
# Class name --> cup
# Speed: 2.3ms preprocess, 120.2ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 cup, 121.6ms
# Confidence ---> 0.7
# Class name --> person
# Confidence ---> 0.45
# Class name --> person
# Confidence ---> 0.34
# Class name --> cup
# Speed: 1.9ms preprocess, 121.6ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 cup, 118.5ms
# Confidence ---> 0.75
# Class name --> person
# Confidence ---> 0.57
# Class name --> person
# Confidence ---> 0.28
# Class name --> cup
# Speed: 2.3ms preprocess, 118.5ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 cup, 135.4ms
# Confidence ---> 0.8
# Class name --> person
# Confidence ---> 0.55
# Class name --> person
# Confidence ---> 0.51
# Class name --> cup
# Speed: 1.4ms preprocess, 135.4ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 cup, 125.4ms
# Confidence ---> 0.77
# Class name --> person
# Confidence ---> 0.6
# Class name --> person
# Confidence ---> 0.43
# Class name --> cup
# Speed: 2.1ms preprocess, 125.4ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 cup, 124.7ms
# Confidence ---> 0.76
# Class name --> person
# Confidence ---> 0.6
# Class name --> person
# Confidence ---> 0.4
# Class name --> cup
# Speed: 2.3ms preprocess, 124.7ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 cup, 124.0ms
# Confidence ---> 0.74
# Class name --> person
# Confidence ---> 0.56
# Class name --> person
# Confidence ---> 0.4
# Class name --> cup
# Speed: 2.9ms preprocess, 124.0ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 cup, 124.8ms
# Confidence ---> 0.81
# Class name --> person
# Confidence ---> 0.45
# Class name --> person
# Confidence ---> 0.42
# Class name --> cup
# Speed: 1.6ms preprocess, 124.8ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 cup, 123.2ms
# Confidence ---> 0.64
# Class name --> person
# Confidence ---> 0.61
# Class name --> person
# Confidence ---> 0.39
# Class name --> cup
# Speed: 1.3ms preprocess, 123.2ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 124.7ms
# Confidence ---> 0.76
# Class name --> person
# Confidence ---> 0.56
# Class name --> person
# Speed: 3.0ms preprocess, 124.7ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 cup, 133.4ms
# Confidence ---> 0.77
# Class name --> person
# Confidence ---> 0.53
# Class name --> person
# Confidence ---> 0.39
# Class name --> cup
# Speed: 2.0ms preprocess, 133.4ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 snowboard, 1 cup, 127.5ms
# Confidence ---> 0.69
# Class name --> person
# Confidence ---> 0.6
# Class name --> person
# Confidence ---> 0.56
# Class name --> cup
# Confidence ---> 0.35
# Class name --> snowboard
# Speed: 2.7ms preprocess, 127.5ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 cup, 126.4ms
# Confidence ---> 0.73
# Class name --> person
# Confidence ---> 0.57
# Class name --> person
# Confidence ---> 0.35
# Class name --> cup
# Speed: 2.1ms preprocess, 126.4ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 snowboard, 1 cup, 119.8ms
# Confidence ---> 0.65
# Class name --> person
# Confidence ---> 0.57
# Class name --> person
# Confidence ---> 0.36
# Class name --> cup
# Confidence ---> 0.35
# Class name --> snowboard
# Speed: 1.3ms preprocess, 119.8ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 snowboard, 1 cup, 122.8ms
# Confidence ---> 0.67
# Class name --> person
# Confidence ---> 0.58
# Class name --> person
# Confidence ---> 0.45
# Class name --> cup
# Confidence ---> 0.34
# Class name --> snowboard
# Speed: 2.5ms preprocess, 122.8ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 cup, 121.7ms
# Confidence ---> 0.71
# Class name --> person
# Confidence ---> 0.64
# Class name --> person
# Confidence ---> 0.35
# Class name --> cup
# Speed: 2.2ms preprocess, 121.7ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 117.7ms
# Confidence ---> 0.79
# Class name --> person
# Confidence ---> 0.56
# Class name --> person
# Speed: 1.3ms preprocess, 117.7ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 snowboard, 1 cup, 134.3ms
# Confidence ---> 0.7
# Class name --> person
# Confidence ---> 0.65
# Class name --> person
# Confidence ---> 0.4
# Class name --> snowboard
# Confidence ---> 0.32
# Class name --> cup
# Speed: 1.4ms preprocess, 134.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 cup, 124.1ms
# Confidence ---> 0.78
# Class name --> person
# Confidence ---> 0.58
# Class name --> person
# Confidence ---> 0.55
# Class name --> cup
# Speed: 1.8ms preprocess, 124.1ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 snowboard, 1 cup, 120.2ms
# Confidence ---> 0.7
# Class name --> person
# Confidence ---> 0.6
# Class name --> person
# Confidence ---> 0.29
# Class name --> snowboard
# Confidence ---> 0.28
# Class name --> cup
# Speed: 1.3ms preprocess, 120.2ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 snowboard, 1 cup, 121.2ms
# Confidence ---> 0.69
# Class name --> person
# Confidence ---> 0.58
# Class name --> person
# Confidence ---> 0.4
# Class name --> cup
# Confidence ---> 0.31
# Class name --> snowboard
# Speed: 3.2ms preprocess, 121.2ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 cup, 125.0ms
# Confidence ---> 0.74
# Class name --> person
# Confidence ---> 0.58
# Class name --> person
# Confidence ---> 0.3
# Class name --> cup
# Speed: 2.6ms preprocess, 125.0ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 cup, 126.6ms
# Confidence ---> 0.65
# Class name --> person
# Confidence ---> 0.59
# Class name --> person
# Confidence ---> 0.34
# Class name --> cup
# Speed: 2.1ms preprocess, 126.6ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 snowboard, 1 cup, 120.5ms
# Confidence ---> 0.63
# Class name --> person
# Confidence ---> 0.58
# Class name --> person
# Confidence ---> 0.43
# Class name --> cup
# Confidence ---> 0.37
# Class name --> snowboard
# Speed: 1.6ms preprocess, 120.5ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cup, 122.6ms
# Confidence ---> 0.74
# Class name --> person
# Confidence ---> 0.37
# Class name --> cup
# Speed: 1.3ms preprocess, 122.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 124.6ms
# Confidence ---> 0.91
# Class name --> person
# Speed: 2.5ms preprocess, 124.6ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 123.1ms
# Confidence ---> 0.92
# Class name --> person
# Speed: 2.1ms preprocess, 123.1ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 123.4ms
# Confidence ---> 0.91
# Class name --> person
# Speed: 1.4ms preprocess, 123.4ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 125.5ms
# Confidence ---> 0.9
# Class name --> person
# Speed: 2.9ms preprocess, 125.5ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 122.9ms
# Confidence ---> 0.91
# Class name --> person
# Speed: 2.1ms preprocess, 122.9ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 124.0ms
# Confidence ---> 0.93
# Class name --> person
# Speed: 2.3ms preprocess, 124.0ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cup, 130.4ms
# Confidence ---> 0.93
# Class name --> person
# Confidence ---> 0.27
# Class name --> cup
# Speed: 2.1ms preprocess, 130.4ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cup, 138.0ms
# Confidence ---> 0.93
# Class name --> person
# Confidence ---> 0.34
# Class name --> cup
# Speed: 2.2ms preprocess, 138.0ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cup, 126.1ms
# Confidence ---> 0.93
# Class name --> person
# Confidence ---> 0.53
# Class name --> cup
# Speed: 2.5ms preprocess, 126.1ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cup, 135.0ms
# Confidence ---> 0.94
# Class name --> person
# Confidence ---> 0.35
# Class name --> cup
# Speed: 2.2ms preprocess, 135.0ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 134.0ms
# Confidence ---> 0.94
# Class name --> person
# Speed: 2.4ms preprocess, 134.0ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 132.6ms
# Confidence ---> 0.93
# Class name --> person
# Speed: 2.2ms preprocess, 132.6ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 131.2ms
# Confidence ---> 0.93
# Class name --> person
# Speed: 2.2ms preprocess, 131.2ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 125.7ms
# Confidence ---> 0.94
# Class name --> person
# Speed: 2.4ms preprocess, 125.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 132.0ms
# Confidence ---> 0.94
# Class name --> person
# Speed: 2.2ms preprocess, 132.0ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 135.6ms
# Confidence ---> 0.94
# Class name --> person
# Speed: 2.1ms preprocess, 135.6ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 145.6ms
# Confidence ---> 0.93
# Class name --> person
# Speed: 3.2ms preprocess, 145.6ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 130.6ms
# Confidence ---> 0.93
# Class name --> person
# Speed: 2.2ms preprocess, 130.6ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 132.1ms
# Confidence ---> 0.94
# Class name --> person
# Speed: 2.2ms preprocess, 132.1ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 138.4ms
# Confidence ---> 0.91
# Class name --> person
# Speed: 2.5ms preprocess, 138.4ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)

# %%
# Lista de índices de clases de interés
clases_interes = [0, 1, 2]

# %%
# Configuramos la captura de video desde la cámara
captura = cv2.VideoCapture(0) # Se abre la cámara por defecto

# Establecemos el ancho y alto de la imagen
captura.set(cv2.CAP_PROP_FRAME_WIDTH, 640) # Ancho de la imagen
captura.set(cv2.CAP_PROP_FRAME_HEIGHT, 480) # Alto de la imagen

# Iniciamos un bucle para procesar los fotogramas de la cámara
while True:
    success, img = captura.read() # Capturamos un fotograma

    # Realizamos la detección de objetos en la imagen capturada (usando el modelo de YOLO pre-entrenado que cargamos anteriormente)
    results = model(img, stream=True)

    # Procesamos los resultados de la detección
    for r in results:
        boxes = r.boxes

        # Iteramos sobre las cajas delimitadoras detectadas
        for box in boxes:
            # Obtenemos el nombre de la clase detectada
            cls = int(box.cls[0])

            # Solo procesamos la detección si la clase es de interés
            if cls in clases_interes:
                # Obtenemos las coordenadas de la caja delimitadora
                x1, y1, x2, y2 = box.xyxy[0]
                x1, y1, x2, y2 = int(x1), int(y1), int(x2), int(y2) # Convertimos a valores enteros

                # Dibujamos la caja delimitadora en la imagen
                cv2.rectangle(img, (x1, y1), (x2, y2), (255, 0, 255), 1)

                # Obtenemos la confianza de la detección
                confidence = math.ceil((box.conf[0]*100))/100
                print("Confidence --->",confidence)

                print("Class name -->", classNames[cls])

                # Mostramos el nombre de la clase junto a la caja delimitadora
                org = [x1, y1]
                font = cv2.FONT_HERSHEY_SIMPLEX
                fontScale = 1
                color = (255, 0, 0) # Color: Azul (formato BGR)
                thickness = 1
                cv2.putText(img, classNames[cls], org, font, fontScale, color, thickness)

    # Mostramos la imagen con las detecciones
    cv2.imshow('Webcam', img)

    # Salimos del bucle si se presiona la tecla 'q'
    #if cv2.waitKey(1) == ord('q'):
    if cv2.waitKey(10) & 0xFF == ord('q'):
        break

# Liberamos la cámara y cerramos todas las ventanas
captura.release()
cv2.destroyAllWindows()
# Out:
# 0: 480x640 1 person, 125.0ms
# Confidence ---> 0.93
# Class name --> person
# Speed: 2.4ms preprocess, 125.0ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 124.9ms
# Confidence ---> 0.93
# Class name --> person
# Speed: 1.7ms preprocess, 124.9ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 120.7ms
# Confidence ---> 0.93
# Class name --> person
# Speed: 2.0ms preprocess, 120.7ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 118.3ms
# Confidence ---> 0.93
# Class name --> person
# Speed: 1.9ms preprocess, 118.3ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 122.8ms
# Confidence ---> 0.93
# Class name --> person
# Speed: 1.3ms preprocess, 122.8ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 122.9ms
# Confidence ---> 0.93
# Class name --> person
# Speed: 1.7ms preprocess, 122.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 123.0ms
# Confidence ---> 0.93
# Class name --> person
# Speed: 1.4ms preprocess, 123.0ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 121.9ms
# Confidence ---> 0.93
# Class name --> person
# Speed: 1.4ms preprocess, 121.9ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 123.9ms
# Confidence ---> 0.93
# Class name --> person
# Speed: 2.3ms preprocess, 123.9ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 120.9ms
# Confidence ---> 0.93
# Class name --> person
# Speed: 1.5ms preprocess, 120.9ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 122.2ms
# Confidence ---> 0.93
# Class name --> person
# Speed: 1.3ms preprocess, 122.2ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 120.1ms
# Confidence ---> 0.93
# Class name --> person
# Speed: 1.3ms preprocess, 120.1ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 120.8ms
# Confidence ---> 0.93
# Class name --> person
# Speed: 1.9ms preprocess, 120.8ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 133.4ms
# Confidence ---> 0.94
# Class name --> person
# Speed: 1.8ms preprocess, 133.4ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 126.8ms
# Confidence ---> 0.94
# Class name --> person
# Speed: 1.4ms preprocess, 126.8ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 123.3ms
# Confidence ---> 0.93
# Class name --> person
# Speed: 1.6ms preprocess, 123.3ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 125.7ms
# Confidence ---> 0.94
# Class name --> person
# Speed: 1.4ms preprocess, 125.7ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 120.8ms
# Confidence ---> 0.93
# Class name --> person
# Speed: 1.7ms preprocess, 120.8ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 120.1ms
# Confidence ---> 0.93
# Class name --> person
# Speed: 1.3ms preprocess, 120.1ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 121.1ms
# Confidence ---> 0.95
# Class name --> person
# Speed: 1.3ms preprocess, 121.1ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 119.5ms
# Confidence ---> 0.94
# Class name --> person
# Speed: 1.4ms preprocess, 119.5ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 131.5ms
# Confidence ---> 0.94
# Class name --> person
# Speed: 1.8ms preprocess, 131.5ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 123.1ms
# Confidence ---> 0.94
# Class name --> person
# Speed: 1.4ms preprocess, 123.1ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 121.0ms
# Confidence ---> 0.94
# Class name --> person
# Speed: 1.5ms preprocess, 121.0ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 125.6ms
# Confidence ---> 0.94
# Class name --> person
# Speed: 1.4ms preprocess, 125.6ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 129.6ms
# Confidence ---> 0.94
# Class name --> person
# Speed: 1.2ms preprocess, 129.6ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 125.6ms
# Confidence ---> 0.94
# Class name --> person
# Speed: 1.4ms preprocess, 125.6ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 124.0ms
# Confidence ---> 0.94
# Class name --> person
# Speed: 1.8ms preprocess, 124.0ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 123.3ms
# Confidence ---> 0.94
# Class name --> person
# Speed: 1.4ms preprocess, 123.3ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 125.5ms
# Confidence ---> 0.94
# Class name --> person
# Speed: 2.3ms preprocess, 125.5ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 123.3ms
# Confidence ---> 0.93
# Class name --> person
# Speed: 1.5ms preprocess, 123.3ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 123.6ms
# Confidence ---> 0.93
# Class name --> person
# Speed: 1.3ms preprocess, 123.6ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cup, 124.5ms
# Confidence ---> 0.92
# Class name --> person
# Speed: 1.8ms preprocess, 124.5ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 125.7ms
# Confidence ---> 0.92
# Class name --> person
# Speed: 1.3ms preprocess, 125.7ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cup, 131.1ms
# Confidence ---> 0.93
# Class name --> person
# Speed: 1.7ms preprocess, 131.1ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 126.7ms
# Confidence ---> 0.93
# Class name --> person
# Speed: 1.7ms preprocess, 126.7ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 118.5ms
# Confidence ---> 0.94
# Class name --> person
# Speed: 1.7ms preprocess, 118.5ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 120.1ms
# Confidence ---> 0.94
# Class name --> person
# Speed: 1.6ms preprocess, 120.1ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 121.0ms
# Confidence ---> 0.93
# Class name --> person
# Speed: 1.2ms preprocess, 121.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 118.8ms
# Confidence ---> 0.93
# Class name --> person
# Speed: 1.5ms preprocess, 118.8ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 122.9ms
# Confidence ---> 0.94
# Class name --> person
# Speed: 1.5ms preprocess, 122.9ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 136.5ms
# Confidence ---> 0.94
# Class name --> person
# Speed: 1.4ms preprocess, 136.5ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 121.4ms
# Confidence ---> 0.94
# Class name --> person
# Speed: 1.7ms preprocess, 121.4ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 121.5ms
# Confidence ---> 0.94
# Class name --> person
# Speed: 1.4ms preprocess, 121.5ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 123.3ms
# Confidence ---> 0.95
# Class name --> person
# Speed: 1.3ms preprocess, 123.3ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 117.7ms
# Confidence ---> 0.94
# Class name --> person
# Speed: 1.5ms preprocess, 117.7ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 119.5ms
# Confidence ---> 0.94
# Class name --> person
# Speed: 1.5ms preprocess, 119.5ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 125.6ms
# Confidence ---> 0.94
# Class name --> person
# Speed: 1.3ms preprocess, 125.6ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 125.6ms
# Confidence ---> 0.94
# Class name --> person
# Speed: 1.6ms preprocess, 125.6ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 125.2ms
# Confidence ---> 0.95
# Class name --> person
# Speed: 1.5ms preprocess, 125.2ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 128.2ms
# Confidence ---> 0.95
# Class name --> person
# Speed: 1.3ms preprocess, 128.2ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 130.2ms
# Confidence ---> 0.94
# Class name --> person
# Speed: 1.9ms preprocess, 130.2ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 127.2ms
# Confidence ---> 0.94
# Class name --> person
# Speed: 1.6ms preprocess, 127.2ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 124.0ms
# Confidence ---> 0.94
# Class name --> person
# Speed: 1.6ms preprocess, 124.0ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 tie, 121.0ms
# Confidence ---> 0.92
# Class name --> person
# Speed: 1.3ms preprocess, 121.0ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 120.6ms
# Confidence ---> 0.92
# Class name --> person
# Confidence ---> 0.45
# Class name --> person
# Speed: 1.5ms preprocess, 120.6ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 124.2ms
# Confidence ---> 0.93
# Class name --> person
# Speed: 1.5ms preprocess, 124.2ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 120.6ms
# Confidence ---> 0.93
# Class name --> person
# Speed: 1.1ms preprocess, 120.6ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 140.2ms
# Confidence ---> 0.92
# Class name --> person
# Speed: 1.5ms preprocess, 140.2ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 121.6ms
# Confidence ---> 0.9
# Class name --> person
# Speed: 1.4ms preprocess, 121.6ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 120.2ms
# Confidence ---> 0.93
# Class name --> person
# Speed: 1.7ms preprocess, 120.2ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 120.2ms
# Confidence ---> 0.87
# Class name --> person
# Speed: 1.3ms preprocess, 120.2ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 122.1ms
# Confidence ---> 0.88
# Class name --> person
# Speed: 1.2ms preprocess, 122.1ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 120.8ms
# Confidence ---> 0.9
# Class name --> person
# Speed: 1.4ms preprocess, 120.8ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 119.3ms
# Confidence ---> 0.91
# Class name --> person
# Speed: 1.2ms preprocess, 119.3ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 122.0ms
# Confidence ---> 0.91
# Class name --> person
# Speed: 1.3ms preprocess, 122.0ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 118.5ms
# Confidence ---> 0.91
# Class name --> person
# Speed: 1.4ms preprocess, 118.5ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 120.7ms
# Confidence ---> 0.9
# Class name --> person
# Speed: 1.3ms preprocess, 120.7ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 119.6ms
# Confidence ---> 0.9
# Class name --> person
# Speed: 1.3ms preprocess, 119.6ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 121.2ms
# Confidence ---> 0.9
# Class name --> person
# Speed: 1.9ms preprocess, 121.2ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 cell phones, 119.6ms
# Confidence ---> 0.9
# Class name --> person
# Speed: 1.3ms preprocess, 119.6ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 119.8ms
# Confidence ---> 0.92
# Class name --> person
# Speed: 1.3ms preprocess, 119.8ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 121.1ms
# Confidence ---> 0.89
# Class name --> person
# Speed: 1.4ms preprocess, 121.1ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 119.9ms
# Confidence ---> 0.9
# Class name --> person
# Speed: 2.1ms preprocess, 119.9ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 121.1ms
# Confidence ---> 0.9
# Class name --> person
# Speed: 1.2ms preprocess, 121.1ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 120.3ms
# Confidence ---> 0.89
# Class name --> person
# Speed: 1.6ms preprocess, 120.3ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 119.1ms
# Confidence ---> 0.93
# Class name --> person
# Speed: 2.2ms preprocess, 119.1ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 120.4ms
# Confidence ---> 0.91
# Class name --> person
# Speed: 1.3ms preprocess, 120.4ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 126.3ms
# Confidence ---> 0.81
# Class name --> person
# Speed: 1.9ms preprocess, 126.3ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 122.7ms
# Confidence ---> 0.79
# Class name --> person
# Speed: 1.2ms preprocess, 122.7ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 125.6ms
# Confidence ---> 0.75
# Class name --> person
# Speed: 1.9ms preprocess, 125.6ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 cell phone, 125.4ms
# Confidence ---> 0.73
# Class name --> person
# Confidence ---> 0.26
# Class name --> person
# Speed: 1.4ms preprocess, 125.4ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 120.4ms
# Confidence ---> 0.69
# Class name --> person
# Speed: 1.3ms preprocess, 120.4ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 124.5ms
# Confidence ---> 0.75
# Class name --> person
# Speed: 1.4ms preprocess, 124.5ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 125.2ms
# Confidence ---> 0.79
# Class name --> person
# Speed: 1.8ms preprocess, 125.2ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 126.4ms
# Confidence ---> 0.77
# Class name --> person
# Speed: 1.6ms preprocess, 126.4ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 125.0ms
# Confidence ---> 0.79
# Class name --> person
# Speed: 1.5ms preprocess, 125.0ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 122.2ms
# Confidence ---> 0.78
# Class name --> person
# Speed: 1.4ms preprocess, 122.2ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 121.3ms
# Confidence ---> 0.83
# Class name --> person
# Speed: 1.3ms preprocess, 121.3ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 119.6ms
# Confidence ---> 0.77
# Class name --> person
# Speed: 1.6ms preprocess, 119.6ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 120.4ms
# Confidence ---> 0.78
# Class name --> person
# Speed: 1.6ms preprocess, 120.4ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 123.4ms
# Confidence ---> 0.75
# Class name --> person
# Speed: 1.4ms preprocess, 123.4ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 136.1ms
# Confidence ---> 0.76
# Class name --> person
# Speed: 1.4ms preprocess, 136.1ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 120.8ms
# Confidence ---> 0.77
# Class name --> person
# Speed: 1.3ms preprocess, 120.8ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 121.1ms
# Confidence ---> 0.76
# Class name --> person
# Speed: 1.2ms preprocess, 121.1ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 126.1ms
# Confidence ---> 0.74
# Class name --> person
# Speed: 1.7ms preprocess, 126.1ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 120.8ms
# Confidence ---> 0.89
# Class name --> person
# Speed: 1.3ms preprocess, 120.8ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 119.5ms
# Confidence ---> 0.95
# Class name --> person
# Speed: 1.6ms preprocess, 119.5ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cup, 124.1ms
# Confidence ---> 0.94
# Class name --> person
# Speed: 1.3ms preprocess, 124.1ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cup, 121.1ms
# Confidence ---> 0.95
# Class name --> person
# Speed: 1.5ms preprocess, 121.1ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cup, 122.0ms
# Confidence ---> 0.95
# Class name --> person
# Speed: 1.9ms preprocess, 122.0ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cup, 126.7ms
# Confidence ---> 0.95
# Class name --> person
# Speed: 1.3ms preprocess, 126.7ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cup, 122.7ms
# Confidence ---> 0.94
# Class name --> person
# Speed: 1.6ms preprocess, 122.7ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cup, 121.5ms
# Confidence ---> 0.94
# Class name --> person
# Speed: 1.3ms preprocess, 121.5ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 118.9ms
# Confidence ---> 0.93
# Class name --> person
# Speed: 1.4ms preprocess, 118.9ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
