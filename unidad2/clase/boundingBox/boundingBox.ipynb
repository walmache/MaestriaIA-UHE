# %%
# !pip install opencv-python

# %%
import cv2
import matplotlib.pyplot as plt

# %%
# Cargar la imagen
imagen = cv2.imread('casa.jpg')

# %%
# Mostramos el tamaño de la imagen
print('Tamaño de la imagen: ', imagen.shape)
# Out:
# Tamaño de la imagen:  (576, 768, 3)

# %%
# Definir las coordenadas del bounding box (x1, y1) y (x2, y2) en la imagen (en píxeles)
x1, y1 = 500, 200  # Punto superior izquierdo
x2, y2 = 710, 400  # Punto inferior derecho

# Dibujar el bounding box en la imagen de entrada (imagen) con el método cv2.rectangle (imagen, (x1, y1), (x2, y2), color, grosor)
imagen_rgb = cv2.rectangle(imagen, (x1, y1), (x2, y2), (255,0,0), 5)  # El último argumento es el grosor de la línea

# %%
# Convertir la imagen de BGR a RGB
imagen_rgb = cv2.cvtColor(imagen, cv2.COLOR_BGR2RGB)

# Mostrar la imagen
plt.imshow(imagen_rgb)
plt.show()
