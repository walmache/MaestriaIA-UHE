# %%
# Instalamos las librerías necesarias
# !pip install opencv-python ultralytics
# Out:
# Requirement already satisfied: opencv-python in /home/walmache/MEGA/autoCapacitacion/Maestria-IA/1.percepcionComputacional/repos/practicasPercepcionComputacional/.venv/lib/python3.10/site-packages (4.10.0.82)
# Requirement already satisfied: ultralytics in /home/walmache/MEGA/autoCapacitacion/Maestria-IA/1.percepcionComputacional/repos/practicasPercepcionComputacional/.venv/lib/python3.10/site-packages (8.2.35)
# Requirement already satisfied: numpy>=1.21.2 in /home/walmache/MEGA/autoCapacitacion/Maestria-IA/1.percepcionComputacional/repos/practicasPercepcionComputacional/.venv/lib/python3.10/site-packages (from opencv-python) (1.26.4)
# Requirement already satisfied: matplotlib>=3.3.0 in /home/walmache/MEGA/autoCapacitacion/Maestria-IA/1.percepcionComputacional/repos/practicasPercepcionComputacional/.venv/lib/python3.10/site-packages (from ultralytics) (3.9.0)
# Requirement already satisfied: pillow>=7.1.2 in /home/walmache/MEGA/autoCapacitacion/Maestria-IA/1.percepcionComputacional/repos/practicasPercepcionComputacional/.venv/lib/python3.10/site-packages (from ultralytics) (10.3.0)
# Requirement already satisfied: pyyaml>=5.3.1 in /home/walmache/MEGA/autoCapacitacion/Maestria-IA/1.percepcionComputacional/repos/practicasPercepcionComputacional/.venv/lib/python3.10/site-packages (from ultralytics) (6.0.1)
# Requirement already satisfied: requests>=2.23.0 in /home/walmache/MEGA/autoCapacitacion/Maestria-IA/1.percepcionComputacional/repos/practicasPercepcionComputacional/.venv/lib/python3.10/site-packages (from ultralytics) (2.32.3)
# Requirement already satisfied: scipy>=1.4.1 in /home/walmache/MEGA/autoCapacitacion/Maestria-IA/1.percepcionComputacional/repos/practicasPercepcionComputacional/.venv/lib/python3.10/site-packages (from ultralytics) (1.13.1)
# Requirement already satisfied: torch>=1.8.0 in /home/walmache/MEGA/autoCapacitacion/Maestria-IA/1.percepcionComputacional/repos/practicasPercepcionComputacional/.venv/lib/python3.10/site-packages (from ultralytics) (2.3.1)
# Requirement already satisfied: torchvision>=0.9.0 in /home/walmache/MEGA/autoCapacitacion/Maestria-IA/1.percepcionComputacional/repos/practicasPercepcionComputacional/.venv/lib/python3.10/site-packages (from ultralytics) (0.18.1)
# Requirement already satisfied: tqdm>=4.64.0 in /home/walmache/MEGA/autoCapacitacion/Maestria-IA/1.percepcionComputacional/repos/practicasPercepcionComputacional/.venv/lib/python3.10/site-packages (from ultralytics) (4.66.4)
# Requirement already satisfied: psutil in /home/walmache/MEGA/autoCapacitacion/Maestria-IA/1.percepcionComputacional/repos/practicasPercepcionComputacional/.venv/lib/python3.10/site-packages (from ultralytics) (5.9.8)
# Requirement already satisfied: py-cpuinfo in /home/walmache/MEGA/autoCapacitacion/Maestria-IA/1.percepcionComputacional/repos/practicasPercepcionComputacional/.venv/lib/python3.10/site-packages (from ultralytics) (9.0.0)
# Requirement already satisfied: pandas>=1.1.4 in /home/walmache/MEGA/autoCapacitacion/Maestria-IA/1.percepcionComputacional/repos/practicasPercepcionComputacional/.venv/lib/python3.10/site-packages (from ultralytics) (2.2.2)
# Requirement already satisfied: seaborn>=0.11.0 in /home/walmache/MEGA/autoCapacitacion/Maestria-IA/1.percepcionComputacional/repos/practicasPercepcionComputacional/.venv/lib/python3.10/site-packages (from ultralytics) (0.13.2)
# Requirement already satisfied: ultralytics-thop>=2.0.0 in /home/walmache/MEGA/autoCapacitacion/Maestria-IA/1.percepcionComputacional/repos/practicasPercepcionComputacional/.venv/lib/python3.10/site-packages (from ultralytics) (2.0.0)
# Requirement already satisfied: contourpy>=1.0.1 in /home/walmache/MEGA/autoCapacitacion/Maestria-IA/1.percepcionComputacional/repos/practicasPercepcionComputacional/.venv/lib/python3.10/site-packages (from matplotlib>=3.3.0->ultralytics) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /home/walmache/MEGA/autoCapacitacion/Maestria-IA/1.percepcionComputacional/repos/practicasPercepcionComputacional/.venv/lib/python3.10/site-packages (from matplotlib>=3.3.0->ultralytics) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/walmache/MEGA/autoCapacitacion/Maestria-IA/1.percepcionComputacional/repos/practicasPercepcionComputacional/.venv/lib/python3.10/site-packages (from matplotlib>=3.3.0->ultralytics) (4.53.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/walmache/MEGA/autoCapacitacion/Maestria-IA/1.percepcionComputacional/repos/practicasPercepcionComputacional/.venv/lib/python3.10/site-packages (from matplotlib>=3.3.0->ultralytics) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /home/walmache/MEGA/autoCapacitacion/Maestria-IA/1.percepcionComputacional/repos/practicasPercepcionComputacional/.venv/lib/python3.10/site-packages (from matplotlib>=3.3.0->ultralytics) (24.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/walmache/MEGA/autoCapacitacion/Maestria-IA/1.percepcionComputacional/repos/practicasPercepcionComputacional/.venv/lib/python3.10/site-packages (from matplotlib>=3.3.0->ultralytics) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /home/walmache/MEGA/autoCapacitacion/Maestria-IA/1.percepcionComputacional/repos/practicasPercepcionComputacional/.venv/lib/python3.10/site-packages (from matplotlib>=3.3.0->ultralytics) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /home/walmache/MEGA/autoCapacitacion/Maestria-IA/1.percepcionComputacional/repos/practicasPercepcionComputacional/.venv/lib/python3.10/site-packages (from pandas>=1.1.4->ultralytics) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /home/walmache/MEGA/autoCapacitacion/Maestria-IA/1.percepcionComputacional/repos/practicasPercepcionComputacional/.venv/lib/python3.10/site-packages (from pandas>=1.1.4->ultralytics) (2024.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/walmache/MEGA/autoCapacitacion/Maestria-IA/1.percepcionComputacional/repos/practicasPercepcionComputacional/.venv/lib/python3.10/site-packages (from requests>=2.23.0->ultralytics) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /home/walmache/MEGA/autoCapacitacion/Maestria-IA/1.percepcionComputacional/repos/practicasPercepcionComputacional/.venv/lib/python3.10/site-packages (from requests>=2.23.0->ultralytics) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/walmache/MEGA/autoCapacitacion/Maestria-IA/1.percepcionComputacional/repos/practicasPercepcionComputacional/.venv/lib/python3.10/site-packages (from requests>=2.23.0->ultralytics) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in /home/walmache/MEGA/autoCapacitacion/Maestria-IA/1.percepcionComputacional/repos/practicasPercepcionComputacional/.venv/lib/python3.10/site-packages (from requests>=2.23.0->ultralytics) (2024.6.2)
# Requirement already satisfied: filelock in /home/walmache/MEGA/autoCapacitacion/Maestria-IA/1.percepcionComputacional/repos/practicasPercepcionComputacional/.venv/lib/python3.10/site-packages (from torch>=1.8.0->ultralytics) (3.15.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in /home/walmache/MEGA/autoCapacitacion/Maestria-IA/1.percepcionComputacional/repos/practicasPercepcionComputacional/.venv/lib/python3.10/site-packages (from torch>=1.8.0->ultralytics) (4.12.2)
# Requirement already satisfied: sympy in /home/walmache/MEGA/autoCapacitacion/Maestria-IA/1.percepcionComputacional/repos/practicasPercepcionComputacional/.venv/lib/python3.10/site-packages (from torch>=1.8.0->ultralytics) (1.12.1)
# Requirement already satisfied: networkx in /home/walmache/MEGA/autoCapacitacion/Maestria-IA/1.percepcionComputacional/repos/practicasPercepcionComputacional/.venv/lib/python3.10/site-packages (from torch>=1.8.0->ultralytics) (3.3)
# Requirement already satisfied: jinja2 in /home/walmache/MEGA/autoCapacitacion/Maestria-IA/1.percepcionComputacional/repos/practicasPercepcionComputacional/.venv/lib/python3.10/site-packages (from torch>=1.8.0->ultralytics) (3.1.4)
# Requirement already satisfied: fsspec in /home/walmache/MEGA/autoCapacitacion/Maestria-IA/1.percepcionComputacional/repos/practicasPercepcionComputacional/.venv/lib/python3.10/site-packages (from torch>=1.8.0->ultralytics) (2024.6.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /home/walmache/MEGA/autoCapacitacion/Maestria-IA/1.percepcionComputacional/repos/practicasPercepcionComputacional/.venv/lib/python3.10/site-packages (from torch>=1.8.0->ultralytics) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /home/walmache/MEGA/autoCapacitacion/Maestria-IA/1.percepcionComputacional/repos/practicasPercepcionComputacional/.venv/lib/python3.10/site-packages (from torch>=1.8.0->ultralytics) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /home/walmache/MEGA/autoCapacitacion/Maestria-IA/1.percepcionComputacional/repos/practicasPercepcionComputacional/.venv/lib/python3.10/site-packages (from torch>=1.8.0->ultralytics) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==8.9.2.26 in /home/walmache/MEGA/autoCapacitacion/Maestria-IA/1.percepcionComputacional/repos/practicasPercepcionComputacional/.venv/lib/python3.10/site-packages (from torch>=1.8.0->ultralytics) (8.9.2.26)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /home/walmache/MEGA/autoCapacitacion/Maestria-IA/1.percepcionComputacional/repos/practicasPercepcionComputacional/.venv/lib/python3.10/site-packages (from torch>=1.8.0->ultralytics) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /home/walmache/MEGA/autoCapacitacion/Maestria-IA/1.percepcionComputacional/repos/practicasPercepcionComputacional/.venv/lib/python3.10/site-packages (from torch>=1.8.0->ultralytics) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /home/walmache/MEGA/autoCapacitacion/Maestria-IA/1.percepcionComputacional/repos/practicasPercepcionComputacional/.venv/lib/python3.10/site-packages (from torch>=1.8.0->ultralytics) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /home/walmache/MEGA/autoCapacitacion/Maestria-IA/1.percepcionComputacional/repos/practicasPercepcionComputacional/.venv/lib/python3.10/site-packages (from torch>=1.8.0->ultralytics) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /home/walmache/MEGA/autoCapacitacion/Maestria-IA/1.percepcionComputacional/repos/practicasPercepcionComputacional/.venv/lib/python3.10/site-packages (from torch>=1.8.0->ultralytics) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.20.5 in /home/walmache/MEGA/autoCapacitacion/Maestria-IA/1.percepcionComputacional/repos/practicasPercepcionComputacional/.venv/lib/python3.10/site-packages (from torch>=1.8.0->ultralytics) (2.20.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /home/walmache/MEGA/autoCapacitacion/Maestria-IA/1.percepcionComputacional/repos/practicasPercepcionComputacional/.venv/lib/python3.10/site-packages (from torch>=1.8.0->ultralytics) (12.1.105)
# Requirement already satisfied: triton==2.3.1 in /home/walmache/MEGA/autoCapacitacion/Maestria-IA/1.percepcionComputacional/repos/practicasPercepcionComputacional/.venv/lib/python3.10/site-packages (from torch>=1.8.0->ultralytics) (2.3.1)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /home/walmache/MEGA/autoCapacitacion/Maestria-IA/1.percepcionComputacional/repos/practicasPercepcionComputacional/.venv/lib/python3.10/site-packages (from nvidia-cusolver-cu12==11.4.5.107->torch>=1.8.0->ultralytics) (12.5.40)
# Requirement already satisfied: six>=1.5 in /home/walmache/MEGA/autoCapacitacion/Maestria-IA/1.percepcionComputacional/repos/practicasPercepcionComputacional/.venv/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/walmache/MEGA/autoCapacitacion/Maestria-IA/1.percepcionComputacional/repos/practicasPercepcionComputacional/.venv/lib/python3.10/site-packages (from jinja2->torch>=1.8.0->ultralytics) (2.1.5)
# Requirement already satisfied: mpmath<1.4.0,>=1.1.0 in /home/walmache/MEGA/autoCapacitacion/Maestria-IA/1.percepcionComputacional/repos/practicasPercepcionComputacional/.venv/lib/python3.10/site-packages (from sympy->torch>=1.8.0->ultralytics) (1.3.0)

# %%
# Importamos las librerías necesarias
from ultralytics import YOLO
import cv2
import math

# %%
# Cargamos el modelo YOLO pre-entrenado en COCO dataset
model = YOLO("yolo-Weights/yolov8n.pt")

# %%
# Revisamos las clases que puede detectar el modelo
model.names
# Out:
# {0: 'person',
#  1: 'bicycle',
#  2: 'car',
#  3: 'motorcycle',
#  4: 'airplane',
#  5: 'bus',
#  6: 'train',
#  7: 'truck',
#  8: 'boat',
#  9: 'traffic light',
#  10: 'fire hydrant',
#  11: 'stop sign',
#  12: 'parking meter',
#  13: 'bench',
#  14: 'bird',
#  15: 'cat',
#  16: 'dog',
#  17: 'horse',
#  18: 'sheep',
#  19: 'cow',
#  20: 'elephant',
#  21: 'bear',
#  22: 'zebra',
#  23: 'giraffe',
#  24: 'backpack',
#  25: 'umbrella',
#  26: 'handbag',
#  27: 'tie',
#  28: 'suitcase',
#  29: 'frisbee',
#  30: 'skis',
#  31: 'snowboard',
#  32: 'sports ball',
#  33: 'kite',
#  34: 'baseball bat',
#  35: 'baseball glove',
#  36: 'skateboard',
#  37: 'surfboard',
#  38: 'tennis racket',
#  39: 'bottle',
#  40: 'wine glass',
#  41: 'cup',
#  42: 'fork',
#  43: 'knife',
#  44: 'spoon',
#  45: 'bowl',
#  46: 'banana',
#  47: 'apple',
#  48: 'sandwich',
#  49: 'orange',
#  50: 'broccoli',
#  51: 'carrot',
#  52: 'hot dog',
#  53: 'pizza',
#  54: 'donut',
#  55: 'cake',
#  56: 'chair',
#  57: 'couch',
#  58: 'potted plant',
#  59: 'bed',
#  60: 'dining table',
#  61: 'toilet',
#  62: 'tv',
#  63: 'laptop',
#  64: 'mouse',
#  65: 'remote',
#  66: 'keyboard',
#  67: 'cell phone',
#  68: 'microwave',
#  69: 'oven',
#  70: 'toaster',
#  71: 'sink',
#  72: 'refrigerator',
#  73: 'book',
#  74: 'clock',
#  75: 'vase',
#  76: 'scissors',
#  77: 'teddy bear',
#  78: 'hair drier',
#  79: 'toothbrush'}

# %%
# Definimos una lista de nombres con todas las clases para identificar objetos detectados
classNames = ["person", "bicycle", "car", "motorbike", "aeroplane", "bus", "train", "truck", "boat",
              "traffic light", "fire hydrant", "stop sign", "parking meter", "bench", "bird", "cat",
              "dog", "horse", "sheep", "cow", "elephant", "bear", "zebra", "giraffe", "backpack", "umbrella",
              "handbag", "tie", "suitcase", "frisbee", "skis", "snowboard", "sports ball", "kite", "baseball bat",
              "baseball glove", "skateboard", "surfboard", "tennis racket", "bottle", "wine glass", "cup",
              "fork", "knife", "spoon", "bowl", "banana", "apple", "sandwich", "orange", "broccoli",
              "carrot", "hot dog", "pizza", "donut", "cake", "chair", "sofa", "pottedplant", "bed",
              "diningtable", "toilet", "tvmonitor", "laptop", "mouse", "remote", "keyboard", "cell phone",
              "microwave", "oven", "toaster", "sink", "refrigerator", "book", "clock", "vase", "scissors",
              "teddy bear", "hair drier", "toothbrush"
              ] # Aquí se enumeran todas las clases

# %%
# Configuramos la captura de video desde la cámara
captura = cv2.VideoCapture(0) # Se abre la cámara por defecto

# Establecemos el ancho y alto de la imagen
captura.set(cv2.CAP_PROP_FRAME_WIDTH, 640) # Ancho de la imagen
captura.set(cv2.CAP_PROP_FRAME_HEIGHT, 480) # Alto de la imagen

# Iniciamos un bucle para procesar los fotogramas de la cámara
while True:
    success, img = captura.read() # Capturamos un fotograma

    # Realizamos la detección de objetos en la imagen capturada (usando el modelo de YOLO pre-entrenado que cargamos anteriormente)
    results = model(img, stream=True)

   # Procesamos los resultados de la detección
    for r in results:
        boxes = r.boxes

        # Iteramos sobre las cajas delimitadoras detectadas
        for box in boxes:
            # Obtenemos las coordenadas de la caja delimitadora
            x1, y1, x2, y2 = box.xyxy[0]
            x1, y1, x2, y2 = int(x1), int(y1), int(x2), int(y2) # Convertimos a valores enteros

            # Dibujamos la caja delimitadora en la imagen
            cv2.rectangle(img, (x1, y1), (x2, y2), (255, 0, 255), 1)

            # Obtenemos la confianza de la detección
            confidence = math.ceil((box.conf[0]*100))/100
            print("Confidence --->",confidence)

            # Obtenemos el nombre de la clase detectada
            cls = int(box.cls[0])
            print("Class name -->", classNames[cls])

            # Mostramos el nombre de la clase junto a la caja delimitadora
            org = [x1, y1]
            font = cv2.FONT_HERSHEY_SIMPLEX
            fontScale = 1
            color = (255, 0, 0) # Color: Azul (formato BGR)
            thickness = 1
            cv2.putText(img, classNames[cls], org, font, fontScale, color, thickness)

    # Mostramos la imagen con las detecciones
    cv2.imshow('Webcam', img)

    # Salimos del bucle si se presiona la tecla 'q'
    #if cv2.waitKey(1) == ord('q'):
    if cv2.waitKey(10) & 0xFF == ord('q'):
        break

# Liberamos la cámara y cerramos todas las ventanas
captura.release()
cv2.destroyAllWindows()
# Out:
# 0: 480x640 1 tv, 206.9ms
# Confidence ---> 0.73
# Class name --> tvmonitor
# Speed: 16.8ms preprocess, 206.9ms inference, 8.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 tv, 190.0ms
# Confidence ---> 0.75
# Class name --> tvmonitor
# Speed: 1.9ms preprocess, 190.0ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 tv, 246.2ms
# Confidence ---> 0.76
# Class name --> tvmonitor
# Speed: 2.7ms preprocess, 246.2ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 tv, 182.9ms
# Confidence ---> 0.76
# Class name --> tvmonitor
# Speed: 3.0ms preprocess, 182.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 tv, 196.1ms
# Confidence ---> 0.79
# Class name --> tvmonitor
# Speed: 3.6ms preprocess, 196.1ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 222.1ms
# Confidence ---> 0.91
# Class name --> person
# Confidence ---> 0.9
# Class name --> person
# Confidence ---> 0.4
# Class name --> person
# Speed: 2.4ms preprocess, 222.1ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 197.6ms
# Confidence ---> 0.89
# Class name --> person
# Confidence ---> 0.89
# Class name --> person
# Confidence ---> 0.3
# Class name --> person
# Speed: 4.4ms preprocess, 197.6ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 187.8ms
# Confidence ---> 0.92
# Class name --> person
# Confidence ---> 0.91
# Class name --> person
# Speed: 4.3ms preprocess, 187.8ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 187.1ms
# Confidence ---> 0.92
# Class name --> person
# Confidence ---> 0.91
# Class name --> person
# Confidence ---> 0.31
# Class name --> person
# Speed: 3.6ms preprocess, 187.1ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 236.5ms
# Confidence ---> 0.92
# Class name --> person
# Confidence ---> 0.89
# Class name --> person
# Speed: 3.5ms preprocess, 236.5ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 179.8ms
# Confidence ---> 0.91
# Class name --> person
# Confidence ---> 0.91
# Class name --> person
# Confidence ---> 0.35
# Class name --> person
# Speed: 2.9ms preprocess, 179.8ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 188.6ms
# Confidence ---> 0.92
# Class name --> person
# Confidence ---> 0.92
# Class name --> person
# Confidence ---> 0.4
# Class name --> person
# Speed: 3.4ms preprocess, 188.6ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 188.7ms
# Confidence ---> 0.92
# Class name --> person
# Confidence ---> 0.85
# Class name --> person
# Confidence ---> 0.35
# Class name --> person
# Speed: 2.1ms preprocess, 188.7ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 184.8ms
# Confidence ---> 0.91
# Class name --> person
# Confidence ---> 0.86
# Class name --> person
#
0ms
# Confidence ---> 0.9
# Class name --> person
# Confidence ---> 0.85
# Class name --> person
# Confidence ---> 0.28
# Class name --> person
# Speed: 4.2ms preprocess, 167.0ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 165.8ms
# Confidence ---> 0.9
# Class name --> person
# Confidence ---> 0.9
# Class name --> person
# Confidence ---> 0.6
# Class name --> person
# Speed: 2.6ms preprocess, 165.8ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 230.3ms
# Confidence ---> 0.91
# Class name --> person
# Confidence ---> 0.91
# Class name --> person
# Confidence ---> 0.53
# Class name --> person
# Speed: 3.5ms preprocess, 230.3ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 223.2ms
# Confidence ---> 0.89
# Class name --> person
# Confidence ---> 0.88
# Class name --> person
# Confidence ---> 0.52
# Class name --> person
# Speed: 4.0ms preprocess, 223.2ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 214.0ms
# Confidence ---> 0.91
# Class name --> person
# Confidence ---> 0.9
# Class name --> person
# Confidence ---> 0.58
# Class name --> person
# Speed: 4.9ms preprocess, 214.0ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 217.1ms
# Confidence ---> 0.89
# Class name --> person
# Confidence ---> 0.88
# Class name --> person
# Confidence ---> 0.61
# Class name --> person
# Speed: 4.4ms preprocess, 217.1ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 219.5ms
# Confidence ---> 0.9
# Class name --> person
# Confidence ---> 0.89
# Class name --> person
# Confidence ---> 0.53
# Class name --> person
# Speed: 3.5ms preprocess, 219.5ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 234.7ms
# Confidence ---> 0.91
# Class name --> person
# Confidence ---> 0.89
# Class name --> person
# Confidence ---> 0.49
# Class name --> person
# Speed: 4.1ms preprocess, 234.7ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 192.4ms
# Confidence ---> 0.91
# Class name --> person
# Confidence ---> 0.91
# Class name --> person
# Confidence ---> 0.57
# Class name --> person
# Speed: 3.1ms preprocess, 192.4ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 181.6ms
# Confidence ---> 0.9
# Class name --> person
# Confidence ---> 0.89
# Class name --> person
# Confidence ---> 0.56
# Class name --> person
# Speed: 3.2ms preprocess, 181.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 173.4ms
# Confidence ---> 0.9
# Class name --> person
# Confidence ---> 0.9
# Class name --> person
# Confidence ---> 0.55
# Class name --> person
# Speed: 3.8ms preprocess, 173.4ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 191.0ms
# Confidence ---> 0.91
# Class name --> person
# Confidence ---> 0.9
# Class name --> person
# Confidence ---> 0.38
# Class name --> person
# Speed: 3.2ms preprocess, 191.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 233.0ms
# Confidence ---> 0.91
# Class name --> person
# Confidence ---> 0.82
# Class name --> person
# Confidence ---> 0.43
# Class name --> person
# Speed: 2.6ms preprocess, 233.0ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 190.7ms
# Confidence ---> 0.91
# Class name --> person
# Confidence ---> 0.87
# Class name --> person
# Confidence ---> 0.55
# Class name --> person
# Speed: 3.9ms preprocess, 190.7ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 173.3ms
# Confidence ---> 0.91
# Class name --> person
# Confidence ---> 0.91
# Class name --> person
# Confidence ---> 0.55
# Class name --> person
# Speed: 3.9ms preprocess, 173.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 178.8ms
# Confidence ---> 0.9
# Class name --> person
# Confidence ---> 0.89
# Class name --> person
# Confidence ---> 0.62
# Class name --> person
# Speed: 2.6ms preprocess, 178.8ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 186.6ms
# Confidence ---> 0.91
# Class name --> person
# Confidence ---> 0.88
# Class name --> person
# Confidence ---> 0.52
# Class name --> person
# Speed: 4.9ms preprocess, 186.6ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 207.6ms
# Confidence ---> 0.9
# Class name --> person
# Confidence ---> 0.88
# Class name --> person
# Confidence ---> 0.33
# Class name --> person
# Speed: 2.9ms preprocess, 207.6ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 192.1ms
# Confidence ---> 0.89
# Class name --> person
# Confidence ---> 0.88
# Class name --> person
# Confidence ---> 0.44
# Class name --> person
# Speed: 3.7ms preprocess, 192.1ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 168.7ms
# Confidence ---> 0.9
# Class name --> person
# Confidence ---> 0.89
# Class name --> person
# Confidence ---> 0.62
# Class name --> person
# Speed: 2.9ms preprocess, 168.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 186.1ms
# Confidence ---> 0.9
# Class name --> person
# Confidence ---> 0.79
# Class name --> person
# Confidence ---> 0.33
# Class name --> person
# Speed: 3.9ms preprocess, 186.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 185.9ms
# Confidence ---> 0.91
# Class name --> person
# Confidence ---> 0.9
# Class name --> person
# Confidence ---> 0.61
# Class name --> person
# Speed: 3.0ms preprocess, 185.9ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 190.2ms
# Confidence ---> 0.9
# Class name --> person
# Confidence ---> 0.9
# Class name --> person
# Confidence ---> 0.44
# Class name --> person
# Speed: 3.1ms preprocess, 190.2ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 186.9ms
# Confidence ---> 0.92
# Class name --> person
# Confidence ---> 0.9
# Class name --> person
# Confidence ---> 0.43
# Class name --> person
# Speed: 3.1ms preprocess, 186.9ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 175.6ms
# Confidence ---> 0.9
# Class name --> person
# Confidence ---> 0.88
# Class name --> person
# Confidence ---> 0.33
# Class name --> person
# Speed: 3.9ms preprocess, 175.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 180.0ms
# Confidence ---> 0.91
# Class name --> person
# Confidence ---> 0.91
# Class name --> person
# Confidence ---> 0.63
# Class name --> person
# Speed: 3.8ms preprocess, 180.0ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 200.4ms
# Confidence ---> 0.9
# Class name --> person
# Confidence ---> 0.85
# Class name --> person
# Confidence ---> 0.56
# Class name --> person
# Speed: 1.6ms preprocess, 200.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 180.0ms
# Confidence ---> 0.9
# Class name --> person
# Confidence ---> 0.89
# Class name --> person
# Confidence ---> 0.35
# Class name --> person
# Speed: 2.6ms preprocess, 180.0ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 170.4ms
# Confidence ---> 0.92
# Class name --> person
# Confidence ---> 0.84
# Class name --> person
# Confidence ---> 0.42
# Class name --> person
# Speed: 2.1ms preprocess, 170.4ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 180.9ms
# Confidence ---> 0.92
# Class name --> person
# Confidence ---> 0.91
# Class name --> person
# Confidence ---> 0.46
# Class name --> person
# Speed: 1.5ms preprocess, 180.9ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 167.2ms
# Confidence ---> 0.91
# Class name --> person
# Confidence ---> 0.91
# Class name --> person
# Confidence ---> 0.5
# Class name --> person
# Speed: 1.5ms preprocess, 167.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 175.9ms
# Confidence ---> 0.92
# Class name --> person
# Confidence ---> 0.91
# Class name --> person
# Confidence ---> 0.38
# Class name --> person
# Speed: 1.7ms preprocess, 175.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 177.3ms
# Confidence ---> 0.91
# Class name --> person
# Confidence ---> 0.91
# Class name --> person
# Confidence ---> 0.7
# Class name --> person
# Speed: 1.6ms preprocess, 177.3ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 201.6ms
# Confidence ---> 0.91
# Class name --> person
# Confidence ---> 0.91
# Class name --> person
# Confidence ---> 0.48
# Class name --> person
# Speed: 2.4ms preprocess, 201.6ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 191.6ms
# Confidence ---> 0.9
# Class name --> person
# Confidence ---> 0.88
# Class name --> person
# Confidence ---> 0.39
# Class name --> person
# Speed: 1.7ms preprocess, 191.6ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 186.0ms
# Confidence ---> 0.9
# Class name --> person
# Confidence ---> 0.87
# Class name --> person
# Confidence ---> 0.43
# Class name --> person
# Speed: 1.7ms preprocess, 186.0ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 177.4ms
# Confidence ---> 0.91
# Class name --> person
# Confidence ---> 0.9
# Class name --> person
# Confidence ---> 0.46
# Class name --> person
# Speed: 1.7ms preprocess, 177.4ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 car, 162.3ms
# Confidence ---> 0.87
# Class name --> person
# Confidence ---> 0.86
# Class name --> person
# Confidence ---> 0.35
# Class name --> car
# Speed: 1.6ms preprocess, 162.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 172.4ms
# Confidence ---> 0.89
# Class name --> person
# Confidence ---> 0.79
# Class name --> person
# Speed: 2.8ms preprocess, 172.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 171.6ms
# Confidence ---> 0.92
# Class name --> person
# Confidence ---> 0.91
# Class name --> person
# Speed: 1.6ms preprocess, 171.6ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 189.1ms
# Confidence ---> 0.95
# Class name --> person
# Confidence ---> 0.91
# Class name --> person
# Speed: 3.9ms preprocess, 189.1ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 178.9ms
# Confidence ---> 0.95
# Class name --> person
# Confidence ---> 0.87
# Class name --> person
# Confidence ---> 0.42
# Class name --> person
# Speed: 1.7ms preprocess, 178.9ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 203.0ms
# Confidence ---> 0.96
# Class name --> person
# Confidence ---> 0.91
# Class name --> person
# Confidence ---> 0.47
# Class name --> person
# Speed: 1.7ms preprocess, 203.0ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 175.0ms
# Confidence ---> 0.95
# Class name --> person
# Confidence ---> 0.91
# Class name --> person
# Confidence ---> 0.56
# Class name --> person
# Speed: 2.5ms preprocess, 175.0ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 169.2ms
# Confidence ---> 0.96
# Class name --> person
# Confidence ---> 0.9
# Class name --> person
# Confidence ---> 0.41
# Class name --> person
# Speed: 1.7ms preprocess, 169.2ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 167.5ms
# Confidence ---> 0.94
# Class name --> person
# Confidence ---> 0.9
# Class name --> person
# Confidence ---> 0.34
# Class name --> person
# Speed: 1.6ms preprocess, 167.5ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 167.5ms
# Confidence ---> 0.96
# Class name --> person
# Confidence ---> 0.89
# Class name --> person
# Confidence ---> 0.33
# Class name --> person
# Speed: 2.9ms preprocess, 167.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 185.1ms
# Confidence ---> 0.96
# Class name --> person
# Confidence ---> 0.91
# Class name --> person
# Confidence ---> 0.42
# Class name --> person
# Speed: 1.6ms preprocess, 185.1ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 175.0ms
# Confidence ---> 0.96
# Class name --> person
# Confidence ---> 0.93
# Class name --> person
# Confidence ---> 0.28
# Class name --> person
# Speed: 2.8ms preprocess, 175.0ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 183.0ms
# Confidence ---> 0.95
# Class name --> person
# Confidence ---> 0.92
# Class name --> person
# Confidence ---> 0.29
# Class name --> person
# Speed: 1.9ms preprocess, 183.0ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 176.5ms
# Confidence ---> 0.94
# Class name --> person
# Confidence ---> 0.91
# Class name --> person
# Confidence ---> 0.54
# Class name --> person
# Speed: 3.8ms preprocess, 176.5ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 162.2ms
# Confidence ---> 0.95
# Class name --> person
# Confidence ---> 0.93
# Class name --> person
# Confidence ---> 0.59
# Class name --> person
# Speed: 2.5ms preprocess, 162.2ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 170.6ms
# Confidence ---> 0.96
# Class name --> person
# Confidence ---> 0.91
# Class name --> person
# Confidence ---> 0.56
# Class name --> person
# Speed: 2.2ms preprocess, 170.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 184.0ms
# Confidence ---> 0.94
# Class name --> person
# Confidence ---> 0.91
# Class name --> person
# Confidence ---> 0.43
# Class name --> person
# Speed: 4.5ms preprocess, 184.0ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 188.2ms
# Confidence ---> 0.94
# Class name --> person
# Confidence ---> 0.9
# Class name --> person
# Confidence ---> 0.45
# Class name --> person
# Speed: 1.7ms preprocess, 188.2ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 174.1ms
# Confidence ---> 0.95
# Class name --> person
# Confidence ---> 0.9
# Class name --> person
# Confidence ---> 0.47
# Class name --> person
# Speed: 2.3ms preprocess, 174.1ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 180.2ms
# Confidence ---> 0.95
# Class name --> person
# Confidence ---> 0.9
# Class name --> person
# Confidence ---> 0.38
# Class name --> person
# Speed: 3.2ms preprocess, 180.2ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 187.3ms
# Confidence ---> 0.96
# Class name --> person
# Confidence ---> 0.92
# Class name --> person
# Confidence ---> 0.54
# Class name --> person
# Speed: 2.3ms preprocess, 187.3ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 191.2ms
# Confidence ---> 0.95
# Class name --> person
# Confidence ---> 0.9
# Class name --> person
# Confidence ---> 0.35
# Class name --> person
# Speed: 2.7ms preprocess, 191.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 177.3ms
# Confidence ---> 0.95
# Class name --> person
# Confidence ---> 0.91
# Class name --> person
# Confidence ---> 0.45
# Class name --> person
# Speed: 2.0ms preprocess, 177.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 188.3ms
# Confidence ---> 0.96
# Class name --> person
# Confidence ---> 0.89
# Class name --> person
# Confidence ---> 0.46
# Class name --> person
# Speed: 2.5ms preprocess, 188.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 224.6ms
# Confidence ---> 0.95
# Class name --> person
# Confidence ---> 0.92
# Class name --> person
# Confidence ---> 0.55
# Class name --> person
# Speed: 1.5ms preprocess, 224.6ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 181.0ms
# Confidence ---> 0.95
# Class name --> person
# Confidence ---> 0.92
# Class name --> person
# Confidence ---> 0.29
# Class name --> person
# Speed: 1.5ms preprocess, 181.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 163.7ms
# Confidence ---> 0.96
# Class name --> person
# Confidence ---> 0.92
# Class name --> person
# Confidence ---> 0.37
# Class name --> person
# Speed: 1.7ms preprocess, 163.7ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 166.9ms
# Confidence ---> 0.95
# Class name --> person
# Confidence ---> 0.89
# Class name --> person
# Confidence ---> 0.4
# Class name --> person
# Speed: 1.8ms preprocess, 166.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 172.9ms
# Confidence ---> 0.95
# Class name --> person
# Confidence ---> 0.9
# Class name --> person
# Confidence ---> 0.38
# Class name --> person
# Speed: 2.9ms preprocess, 172.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 171.5ms
# Confidence ---> 0.96
# Class name --> person
# Confidence ---> 0.9
# Class name --> person
# Confidence ---> 0.29
# Class name --> person
# Speed: 1.6ms preprocess, 171.5ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 cell phone, 164.7ms
# Confidence ---> 0.95
# Class name --> person
# Confidence ---> 0.89
# Class name --> person
# Confidence ---> 0.34
# Class name --> cell phone
# Speed: 1.7ms preprocess, 164.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 166.7ms
# Confidence ---> 0.94
# Class name --> person
# Confidence ---> 0.89
# Class name --> person
# Speed: 2.8ms preprocess, 166.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 169.4ms
# Confidence ---> 0.94
# Class name --> person
# Confidence ---> 0.85
# Class name --> person
# Speed: 3.2ms preprocess, 169.4ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 172.8ms
# Confidence ---> 0.93
# Class name --> person
# Confidence ---> 0.77
# Class name --> person
# Speed: 1.7ms preprocess, 172.8ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 170.4ms
# Confidence ---> 0.94
# Class name --> person
# Confidence ---> 0.59
# Class name --> person
# Speed: 3.6ms preprocess, 170.4ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 175.0ms
# Confidence ---> 0.91
# Class name --> person
# Confidence ---> 0.7
# Class name --> person
# Speed: 4.0ms preprocess, 175.0ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 173.5ms
# Confidence ---> 0.94
# Class name --> person
# Confidence ---> 0.75
# Class name --> person
# Speed: 2.5ms preprocess, 173.5ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 172.0ms
# Confidence ---> 0.94
# Class name --> person
# Confidence ---> 0.64
# Class name --> person
# Speed: 1.7ms preprocess, 172.0ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 179.4ms
# Confidence ---> 0.94
# Class name --> person
# Confidence ---> 0.37
# Class name --> person
# Speed: 1.5ms preprocess, 179.4ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 182.0ms
# Confidence ---> 0.95
# Class name --> person
# Confidence ---> 0.54
# Class name --> person
# Speed: 2.7ms preprocess, 182.0ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 186.0ms
# Confidence ---> 0.94
# Class name --> person
# Confidence ---> 0.69
# Class name --> person
# Speed: 1.8ms preprocess, 186.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 199.5ms
# Confidence ---> 0.94
# Class name --> person
# Confidence ---> 0.71
# Class name --> person
# Speed: 2.4ms preprocess, 199.5ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 180.6ms
# Confidence ---> 0.94
# Class name --> person
# Confidence ---> 0.56
# Class name --> person
# Speed: 3.9ms preprocess, 180.6ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 176.2ms
# Confidence ---> 0.95
# Class name --> person
# Confidence ---> 0.78
# Class name --> person
# Speed: 3.0ms preprocess, 176.2ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 175.9ms
# Confidence ---> 0.94
# Class name --> person
# Confidence ---> 0.73
# Class name --> person
# Speed: 3.5ms preprocess, 175.9ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 cell phone, 170.5ms
# Confidence ---> 0.94
# Class name --> person
# Confidence ---> 0.84
# Class name --> person
# Confidence ---> 0.3
# Class name --> cell phone
# Speed: 3.3ms preprocess, 170.5ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 171.0ms
# Confidence ---> 0.96
# Class name --> person
# Confidence ---> 0.91
# Class name --> person
# Confidence ---> 0.57
# Class name --> person
# Speed: 3.5ms preprocess, 171.0ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 1 cell phone, 172.4ms
# Confidence ---> 0.95
# Class name --> person
# Confidence ---> 0.92
# Class name --> person
# Confidence ---> 0.54
# Class name --> person
# Confidence ---> 0.27
# Class name --> cell phone
# Speed: 3.5ms preprocess, 172.4ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 168.9ms
# Confidence ---> 0.93
# Class name --> person
# Confidence ---> 0.84
# Class name --> person
# Confidence ---> 0.47
# Class name --> person
# Speed: 1.7ms preprocess, 168.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 167.3ms
# Confidence ---> 0.94
# Class name --> person
# Confidence ---> 0.9
# Class name --> person
# Confidence ---> 0.26
# Class name --> person
# Speed: 2.2ms preprocess, 167.3ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 cell phone, 161.1ms
# Confidence ---> 0.95
# Class name --> person
# Confidence ---> 0.91
# Class name --> person
# Confidence ---> 0.26
# Class name --> cell phone
# Speed: 2.1ms preprocess, 161.1ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 168.3ms
# Confidence ---> 0.95
# Class name --> person
# Confidence ---> 0.9
# Class name --> person
# Confidence ---> 0.45
# Class name --> person
# Speed: 2.8ms preprocess, 168.3ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 166.0ms
# Confidence ---> 0.95
# Class name --> person
# Confidence ---> 0.86
# Class name --> person
# Confidence ---> 0.31
# Class name --> person
# Speed: 3.2ms preprocess, 166.0ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 185.5ms
# Confidence ---> 0.95
# Class name --> person
# Confidence ---> 0.87
# Class name --> person
# Confidence ---> 0.47
# Class name --> person
# Speed: 3.2ms preprocess, 185.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 178.2ms
# Confidence ---> 0.95
# Class name --> person
# Confidence ---> 0.88
# Class name --> person
# Confidence ---> 0.64
# Class name --> person
# Speed: 2.1ms preprocess, 178.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 173.3ms
# Confidence ---> 0.96
# Class name --> person
# Confidence ---> 0.9
# Class name --> person
# Confidence ---> 0.43
# Class name --> person
# Speed: 1.6ms preprocess, 173.3ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 177.8ms
# Confidence ---> 0.95
# Class name --> person
# Confidence ---> 0.82
# Class name --> person
# Confidence ---> 0.27
# Class name --> person
# Speed: 1.8ms preprocess, 177.8ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 178.8ms
# Confidence ---> 0.94
# Class name --> person
# Confidence ---> 0.87
# Class name --> person
# Speed: 3.0ms preprocess, 178.8ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 184.1ms
# Confidence ---> 0.93
# Class name --> person
# Confidence ---> 0.83
# Class name --> person
# Speed: 1.6ms preprocess, 184.1ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 213.6ms
# Confidence ---> 0.94
# Class name --> person
# Confidence ---> 0.81
# Class name --> person
# Speed: 4.8ms preprocess, 213.6ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 181.0ms
# Confidence ---> 0.93
# Class name --> person
# Confidence ---> 0.68
# Class name --> person
# Speed: 4.0ms preprocess, 181.0ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 168.2ms
# Confidence ---> 0.92
# Class name --> person
# Confidence ---> 0.63
# Class name --> person
# Speed: 2.9ms preprocess, 168.2ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 178.1ms
# Confidence ---> 0.93
# Class name --> person
# Confidence ---> 0.81
# Class name --> person
# Speed: 3.3ms preprocess, 178.1ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 175.1ms
# Confidence ---> 0.95
# Class name --> person
# Confidence ---> 0.77
# Class name --> person
# Speed: 3.4ms preprocess, 175.1ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 263.3ms
# Confidence ---> 0.94
# Class name --> person
# Confidence ---> 0.63
# Class name --> person
# Speed: 4.0ms preprocess, 263.3ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# ...
# Confidence ---> 0.82
# Class name --> person
# Speed: 3.0ms preprocess, 176.4ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 167.0ms
# Confidence ---> 0.86
# Class name --> person
# Confidence ---> 0.75
# Class name --> person
# Speed: 3.0ms preprocess, 167.0ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 180.1ms
# Confidence ---> 0.86
# Class name --> person
# Confidence ---> 0.77
# Class name --> person
# Speed: 3.8ms preprocess, 180.1ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 190.4ms
# Confidence ---> 0.83
# Class name --> person
# Confidence ---> 0.76
# Class name --> person
# Speed: 4.3ms preprocess, 190.4ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 176.4ms
# Confidence ---> 0.85
# Class name --> person
# Confidence ---> 0.81
# Class name --> person
# Speed: 4.0ms preprocess, 176.4ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 179.8ms
# Confidence ---> 0.83
# Class name --> person
# Confidence ---> 0.76
# Class name --> person
# Speed: 4.0ms preprocess, 179.8ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 170.2ms
# Confidence ---> 0.81
# Class name --> person
# Confidence ---> 0.73
# Class name --> person
# Speed: 3.2ms preprocess, 170.2ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 172.1ms
# Confidence ---> 0.86
# Class name --> person
# Confidence ---> 0.71
# Class name --> person
# Speed: 3.0ms preprocess, 172.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 188.7ms
# Confidence ---> 0.79
# Class name --> person
# Confidence ---> 0.79
# Class name --> person
# Speed: 3.8ms preprocess, 188.7ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 201.1ms
# Confidence ---> 0.86
# Class name --> person
# Confidence ---> 0.72
# Class name --> person
# Speed: 5.2ms preprocess, 201.1ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 167.0ms
# Confidence ---> 0.88
# Class name --> person
# Confidence ---> 0.7
# Class name --> person
# Speed: 2.7ms preprocess, 167.0ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 172.5ms
# Confidence ---> 0.81
# Class name --> person
# Confidence ---> 0.81
# Class name --> person
# Speed: 4.1ms preprocess, 172.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 187.8ms
# Confidence ---> 0.87
# Class name --> person
# Confidence ---> 0.76
# Class name --> person
# Speed: 2.8ms preprocess, 187.8ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 170.5ms
# Confidence ---> 0.85
# Class name --> person
# Confidence ---> 0.79
# Class name --> person
# Speed: 3.0ms preprocess, 170.5ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 175.9ms
# Confidence ---> 0.85
# Class name --> person
# Confidence ---> 0.76
# Class name --> person
# Speed: 4.6ms preprocess, 175.9ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 164.3ms
# Confidence ---> 0.81
# Class name --> person
# Confidence ---> 0.79
# Class name --> person
# Speed: 3.3ms preprocess, 164.3ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 235.2ms
# Confidence ---> 0.89
# Class name --> person
# Confidence ---> 0.84
# Class name --> person
# Speed: 4.2ms preprocess, 235.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 173.9ms
# Confidence ---> 0.85
# Class name --> person
# Confidence ---> 0.82
# Class name --> person
# Speed: 3.1ms preprocess, 173.9ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 243.8ms
# Confidence ---> 0.85
# Class name --> person
# Confidence ---> 0.8
# Class name --> person
# Speed: 3.9ms preprocess, 243.8ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 166.4ms
# Confidence ---> 0.81
# Class name --> person
# Confidence ---> 0.81
# Class name --> person
# Speed: 2.7ms preprocess, 166.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 165.1ms
# Confidence ---> 0.77
# Class name --> person
# Confidence ---> 0.75
# Class name --> person
# Speed: 3.8ms preprocess, 165.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 167.1ms
# Confidence ---> 0.86
# Class name --> person
# Confidence ---> 0.78
# Class name --> person
# Speed: 3.4ms preprocess, 167.1ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 168.2ms
# Confidence ---> 0.84
# Class name --> person
# Confidence ---> 0.8
# Class name --> person
# Speed: 2.9ms preprocess, 168.2ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 192.4ms
# Confidence ---> 0.86
# Class name --> person
# Confidence ---> 0.85
# Class name --> person
# Speed: 3.7ms preprocess, 192.4ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 178.3ms
# Confidence ---> 0.88
# Class name --> person
# Confidence ---> 0.88
# Class name --> person
# Speed: 3.9ms preprocess, 178.3ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 171.9ms
# Confidence ---> 0.89
# Class name --> person
# Confidence ---> 0.84
# Class name --> person
# Speed: 3.1ms preprocess, 171.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 172.3ms
# Confidence ---> 0.89
# Class name --> person
# Confidence ---> 0.86
# Class name --> person
# Speed: 3.5ms preprocess, 172.3ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 178.2ms
# Confidence ---> 0.86
# Class name --> person
# Confidence ---> 0.64
# Class name --> person
# Speed: 3.9ms preprocess, 178.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 222.9ms
# Confidence ---> 0.79
# Class name --> person
# Confidence ---> 0.56
# Class name --> person
# Speed: 3.5ms preprocess, 222.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 184.3ms
# Confidence ---> 0.73
# Class name --> person
# Confidence ---> 0.51
# Class name --> person
# Confidence ---> 0.39
# Class name --> person
# Speed: 3.9ms preprocess, 184.3ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 178.4ms
# Confidence ---> 0.72
# Class name --> person
# Confidence ---> 0.52
# Class name --> person
# Speed: 4.4ms preprocess, 178.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 198.9ms
# Confidence ---> 0.84
# Class name --> person
# Confidence ---> 0.64
# Class name --> person
# Speed: 3.3ms preprocess, 198.9ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 174.8ms
# Confidence ---> 0.77
# Class name --> person
# Confidence ---> 0.72
# Class name --> person
# Speed: 3.2ms preprocess, 174.8ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 182.2ms
# Confidence ---> 0.85
# Class name --> person
# Confidence ---> 0.83
# Class name --> person
# Speed: 4.1ms preprocess, 182.2ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 173.1ms
# Confidence ---> 0.79
# Class name --> person
# Confidence ---> 0.73
# Class name --> person
# Speed: 2.8ms preprocess, 173.1ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 166.5ms
# Confidence ---> 0.8
# Class name --> person
# Confidence ---> 0.77
# Class name --> person
# Speed: 3.5ms preprocess, 166.5ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 188.2ms
# Confidence ---> 0.88
# Class name --> person
# Confidence ---> 0.83
# Class name --> person
# Speed: 3.8ms preprocess, 188.2ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 171.5ms
# Confidence ---> 0.87
# Class name --> person
# Confidence ---> 0.86
# Class name --> person
# Speed: 7.4ms preprocess, 171.5ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 191.5ms
# Confidence ---> 0.85
# Class name --> person
# Confidence ---> 0.85
# Class name --> person
# Speed: 3.6ms preprocess, 191.5ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 186.3ms
# Confidence ---> 0.87
# Class name --> person
# Confidence ---> 0.86
# Class name --> person
# Speed: 3.6ms preprocess, 186.3ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 163.9ms
# Confidence ---> 0.85
# Class name --> person
# Confidence ---> 0.84
# Class name --> person
# Speed: 2.1ms preprocess, 163.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 187.3ms
# Confidence ---> 0.88
# Class name --> person
# Confidence ---> 0.85
# Class name --> person
# Speed: 3.3ms preprocess, 187.3ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 172.9ms
# Confidence ---> 0.89
# Class name --> person
# Confidence ---> 0.82
# Class name --> person
# Confidence ---> 0.36
# Class name --> person
# Speed: 2.9ms preprocess, 172.9ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 166.7ms
# Confidence ---> 0.89
# Class name --> person
# Confidence ---> 0.71
# Class name --> person
# Speed: 3.0ms preprocess, 166.7ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 185.9ms
# Confidence ---> 0.85
# Class name --> person
# Confidence ---> 0.79
# Class name --> person
# Speed: 4.3ms preprocess, 185.9ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 170.4ms
# Confidence ---> 0.87
# Class name --> person
# Confidence ---> 0.77
# Class name --> person
# Speed: 3.7ms preprocess, 170.4ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 193.9ms
# Confidence ---> 0.87
# Class name --> person
# Confidence ---> 0.85
# Class name --> person
# Speed: 5.4ms preprocess, 193.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 178.1ms
# Confidence ---> 0.71
# Class name --> person
# Confidence ---> 0.64
# Class name --> person
# Speed: 3.4ms preprocess, 178.1ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 174.3ms
# Confidence ---> 0.89
# Class name --> person
# Confidence ---> 0.6
# Class name --> person
# Speed: 4.1ms preprocess, 174.3ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 170.3ms
# Confidence ---> 0.92
# Class name --> person
# Confidence ---> 0.52
# Class name --> person
# Speed: 3.0ms preprocess, 170.3ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 204.6ms
# Confidence ---> 0.92
# Class name --> person
# Confidence ---> 0.57
# Class name --> person
# Speed: 3.7ms preprocess, 204.6ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 193.2ms
# Confidence ---> 0.92
# Class name --> person
# Confidence ---> 0.45
# Class name --> person
# Confidence ---> 0.27
# Class name --> person
# Speed: 4.7ms preprocess, 193.2ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 171.6ms
# Confidence ---> 0.92
# Class name --> person
# Confidence ---> 0.64
# Class name --> person
# Speed: 3.1ms preprocess, 171.6ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 204.8ms
# Confidence ---> 0.91
# Class name --> person
# Confidence ---> 0.43
# Class name --> person
# Speed: 4.1ms preprocess, 204.8ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 209.9ms
# Confidence ---> 0.93
# Class name --> person
# Confidence ---> 0.57
# Class name --> person
# Speed: 4.1ms preprocess, 209.9ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 176.2ms
# Confidence ---> 0.92
# Class name --> person
# Confidence ---> 0.58
# Class name --> person
# Speed: 3.3ms preprocess, 176.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 175.6ms
# Confidence ---> 0.54
# Class name --> person
# Confidence ---> 0.43
# Class name --> person
# Confidence ---> 0.4
# Class name --> person
# Speed: 3.5ms preprocess, 175.6ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 179.7ms
# Confidence ---> 0.92
# Class name --> person
# Confidence ---> 0.91
# Class name --> person
# Speed: 3.8ms preprocess, 179.7ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 200.1ms
# Confidence ---> 0.92
# Class name --> person
# Confidence ---> 0.91
# Class name --> person
# Speed: 4.4ms preprocess, 200.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 173.3ms
# Confidence ---> 0.92
# Class name --> person
# Confidence ---> 0.91
# Class name --> person
# Confidence ---> 0.42
# Class name --> person
# Speed: 3.2ms preprocess, 173.3ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 183.4ms
# Confidence ---> 0.92
# Class name --> person
# Confidence ---> 0.9
# Class name --> person
# Confidence ---> 0.29
# Class name --> person
# Speed: 1.8ms preprocess, 183.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 186.6ms
# Confidence ---> 0.91
# Class name --> person
# Confidence ---> 0.91
# Class name --> person
# Confidence ---> 0.3
# Class name --> person
# Speed: 3.0ms preprocess, 186.6ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 191.6ms
# Confidence ---> 0.91
# Class name --> person
# Confidence ---> 0.91
# Class name --> person
# Confidence ---> 0.28
# Class name --> person
# Speed: 3.3ms preprocess, 191.6ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 228.8ms
# Confidence ---> 0.9
# Class name --> person
# Confidence ---> 0.9
# Class name --> person
# Confidence ---> 0.33
# Class name --> person
# Speed: 4.3ms preprocess, 228.8ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 192.9ms
# Confidence ---> 0.9
# Class name --> person
# Confidence ---> 0.89
# Class name --> person
# Speed: 4.0ms preprocess, 192.9ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 215.4ms
# Confidence ---> 0.88
# Class name --> person
# Confidence ---> 0.86
# Class name --> person
# Speed: 4.4ms preprocess, 215.4ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 209.5ms
# Confidence ---> 0.89
# Class name --> person
# Confidence ---> 0.82
# Class name --> person
# Speed: 2.8ms preprocess, 209.5ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 192.2ms
# Confidence ---> 0.9
# Class name --> person
# Confidence ---> 0.83
# Class name --> person
# Speed: 4.2ms preprocess, 192.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 182.7ms
# Confidence ---> 0.88
# Class name --> person
# Confidence ---> 0.82
# Class name --> person
# Speed: 3.0ms preprocess, 182.7ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 173.3ms
# Confidence ---> 0.9
# Class name --> person
# Confidence ---> 0.85
# Class name --> person
# Speed: 4.2ms preprocess, 173.3ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 173.1ms
# Confidence ---> 0.91
# Class name --> person
# Confidence ---> 0.86
# Class name --> person
# Speed: 4.5ms preprocess, 173.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 198.7ms
# Confidence ---> 0.86
# Class name --> person
# Confidence ---> 0.75
# Class name --> person
# Speed: 3.7ms preprocess, 198.7ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 184.6ms
# Confidence ---> 0.87
# Class name --> person
# Confidence ---> 0.84
# Class name --> person
# Speed: 2.3ms preprocess, 184.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)

# %%
# Lista de índices de clases de interés
clases_interes = [0, 1, 2]

# %%
# Configuramos la captura de video desde la cámara
captura = cv2.VideoCapture(0) # Se abre la cámara por defecto

# Establecemos el ancho y alto de la imagen
captura.set(cv2.CAP_PROP_FRAME_WIDTH, 640) # Ancho de la imagen
captura.set(cv2.CAP_PROP_FRAME_HEIGHT, 480) # Alto de la imagen

# Iniciamos un bucle para procesar los fotogramas de la cámara
while True:
    success, img = captura.read() # Capturamos un fotograma

    # Realizamos la detección de objetos en la imagen capturada (usando el modelo de YOLO pre-entrenado que cargamos anteriormente)
    results = model(img, stream=True)

    # Procesamos los resultados de la detección
    for r in results:
        boxes = r.boxes

        # Iteramos sobre las cajas delimitadoras detectadas
        for box in boxes:
            # Obtenemos el nombre de la clase detectada
            cls = int(box.cls[0])

            # Solo procesamos la detección si la clase es de interés
            if cls in clases_interes:
                # Obtenemos las coordenadas de la caja delimitadora
                x1, y1, x2, y2 = box.xyxy[0]
                x1, y1, x2, y2 = int(x1), int(y1), int(x2), int(y2) # Convertimos a valores enteros

                # Dibujamos la caja delimitadora en la imagen
                cv2.rectangle(img, (x1, y1), (x2, y2), (255, 0, 255), 1)

                # Obtenemos la confianza de la detección
                confidence = math.ceil((box.conf[0]*100))/100
                print("Confidence --->",confidence)

                print("Class name -->", classNames[cls])

                # Mostramos el nombre de la clase junto a la caja delimitadora
                org = [x1, y1]
                font = cv2.FONT_HERSHEY_SIMPLEX
                fontScale = 1
                color = (255, 0, 0) # Color: Azul (formato BGR)
                thickness = 1
                cv2.putText(img, classNames[cls], org, font, fontScale, color, thickness)

    # Mostramos la imagen con las detecciones
    cv2.imshow('Webcam', img)

    # Salimos del bucle si se presiona la tecla 'q'
    #if cv2.waitKey(1) == ord('q'):
    if cv2.waitKey(10) & 0xFF == ord('q'):
        break

# Liberamos la cámara y cerramos todas las ventanas
captura.release()
cv2.destroyAllWindows()
# Out:
# 0: 480x640 1 person, 125.0ms
# Confidence ---> 0.93
# Class name --> person
# Speed: 2.4ms preprocess, 125.0ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 124.9ms
# Confidence ---> 0.93
# Class name --> person
# Speed: 1.7ms preprocess, 124.9ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 120.7ms
# Confidence ---> 0.93
# Class name --> person
# Speed: 2.0ms preprocess, 120.7ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 118.3ms
# Confidence ---> 0.93
# Class name --> person
# Speed: 1.9ms preprocess, 118.3ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 122.8ms
# Confidence ---> 0.93
# Class name --> person
# Speed: 1.3ms preprocess, 122.8ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 122.9ms
# Confidence ---> 0.93
# Class name --> person
# Speed: 1